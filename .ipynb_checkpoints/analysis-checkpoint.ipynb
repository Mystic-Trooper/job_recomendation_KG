# %% [markdown]
# Job Recomendation Using Knowledge Graph

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("Resume_Dataset/survey_results_public.csv")
# Out:
# c:\users\hp\appdata\local\programs\python\python310\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
resume_subset= dataset[['Respondent','Country','Student','CompanySize','Dependents','DevType','Gender','JobSatisfaction','LastNewJob','Salary','LanguageWorkedWith','LanguageDesireNextYear','DatabaseWorkedWith','DatabaseDesireNextYear','PlatformWorkedWith','PlatformDesireNextYear','FrameworkWorkedWith','FrameworkDesireNextYear','OperatingSystem','HypotheticalTools1','Age']]
df = pd.DataFrame(resume_subset)
df
# Out:
#        Respondent             Country         Student  \
# 0               1               Kenya              No
# 1               3      United Kingdom              No
# 2               4       United States              No
# 3               5       United States              No
# 4               7        South Africa  Yes, part-time
# ...           ...                 ...             ...
# 98850      101513       United States             NaN
# 98851      101531               Spain  Yes, full-time
# 98852      101541               India  Yes, full-time
# 98853      101544  Russian Federation              No
# 98854      101548            Cambodia             NaN
#
#                     CompanySize Dependents  \
# 0            20 to 99 employees        Yes
# 1      10,000 or more employees        Yes
# 2            20 to 99 employees        NaN
# 3          100 to 499 employees         No
# 4      10,000 or more employees        Yes
# ...                         ...        ...
# 98850                       NaN        NaN
# 98851                       NaN        NaN
# 98852                       NaN        NaN
# 98853                       NaN        NaN
# 98854                       NaN        NaN
#
#                                                  DevType Gender  \
# 0                                   Full-stack developer   Male
# 1      Database administrator;DevOps specialist;Full-...   Male
# 2               Engineering manager;Full-stack developer    NaN
# 3                                   Full-stack developer   Male
# 4      Data or business analyst;Desktop or enterprise...   Male
# ...                                                  ...    ...
# 98850                                                NaN    NaN
# 98851             Back-end developer;Front-end developer    NaN
# 98852                                                NaN    NaN
# 98853                                                NaN    NaN
# 98854                                                NaN    NaN
#
#                           JobSatisfaction                 LastNewJob  Salary  \
# 0                     Extremely satisfied       Less than a year ago     NaN
# 1                 Moderately dissatisfied      More than 4 years ago   51000
# 2                    Moderately satisfied       Less than a year ago     NaN
# 3      Neither satisfied nor dissatisfied       Less than a year ago     NaN
# 4                      Slightly satisfied  Between 1 and 2 years ago  260000
# ...                                   ...                        ...     ...
# 98850                                 NaN                        NaN     NaN
# 98851                                 NaN                        NaN     NaN
# 98852                                 NaN                        NaN     NaN
# 98853                                 NaN                        NaN     NaN
# 98854                                 NaN                        NaN     NaN
#
#        ...                            LanguageDesireNextYear  \
# 0      ...                        JavaScript;Python;HTML;CSS
# 1      ...                                         Go;Python
# 2      ...                                               NaN
# 3      ...  C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4      ...              Assembly;C;C++;Matlab;SQL;Bash/Shell
# ...    ...                                               ...
# 98850  ...                                               NaN
# 98851  ...                                               NaN
# 98852  ...                                               NaN
# 98853  ...                                               NaN
# 98854  ...                                               NaN
#
#                                       DatabaseWorkedWith  \
# 0      Redis;SQL Server;MySQL;PostgreSQL;Amazon RDS/A...
# 1                             Redis;PostgreSQL;Memcached
# 2                                                    NaN
# 3      SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 4                   SQL Server;PostgreSQL;Oracle;IBM Db2
# ...                                                  ...
# 98850                                                NaN
# 98851                                                NaN
# 98852                                                NaN
# 98853                                                NaN
# 98854                                                NaN
#
#                                   DatabaseDesireNextYear  \
# 0      Redis;SQL Server;MySQL;PostgreSQL;Amazon RDS/A...
# 1                                             PostgreSQL
# 2                                                    NaN
# 3      SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 4                              PostgreSQL;Oracle;IBM Db2
# ...                                                  ...
# 98850                                                NaN
# 98851                                                NaN
# 98852                                                NaN
# 98853                                                NaN
# 98854                                                NaN
#
#                       PlatformWorkedWith             PlatformDesireNextYear  \
# 0               AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                                  Linux                              Linux
# 2                                    NaN                                NaN
# 3                                  Azure                              Azure
# 4      Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
# ...                                  ...                                ...
# 98850                                NaN                                NaN
# 98851                                NaN                                NaN
# 98852                                NaN                                NaN
# 98853                                NaN                                NaN
# 98854                                NaN                                NaN
#
#       FrameworkWorkedWith  FrameworkDesireNextYear OperatingSystem  \
# 0            Django;React             Django;React     Linux-based
# 1                  Django                    React     Linux-based
# 2                     NaN                      NaN             NaN
# 3                     NaN  Angular;.NET Core;React         Windows
# 4                     NaN                      NaN         Windows
# ...                   ...                      ...             ...
# 98850                 NaN                      NaN             NaN
# 98851                 NaN                      NaN             NaN
# 98852                 NaN                      NaN             NaN
# 98853                 NaN                      NaN             NaN
# 98854                 NaN                      NaN             NaN
#
#             HypotheticalTools1                Age
# 0         Extremely interested  25 - 34 years old
# 1      A little bit interested  35 - 44 years old
# 2                          NaN                NaN
# 3          Somewhat interested  35 - 44 years old
# 4         Extremely interested  18 - 24 years old
# ...                        ...                ...
# 98850                      NaN                NaN
# 98851                      NaN                NaN
# 98852                      NaN                NaN
# 98853                      NaN                NaN
# 98854                      NaN                NaN
#
# [98855 rows x 21 columns]

# %%
df1 = df.dropna()
df1
# Out:
#        Respondent         Country         Student               CompanySize  \
# 1               3  United Kingdom              No  10,000 or more employees
# 5               8  United Kingdom              No        10 to 19 employees
# 17             27          Sweden              No        10 to 19 employees
# 20             33       Australia              No  1,000 to 4,999 employees
# 22             37  United Kingdom              No        20 to 99 employees
# ...           ...             ...             ...                       ...
# 71505      101560   United States              No  1,000 to 4,999 employees
# 71510      101567       Australia  Yes, full-time  10,000 or more employees
# 71517      101576   United States              No  10,000 or more employees
# 71524      101584   United States  Yes, full-time        20 to 99 employees
# 71526      101587          Canada              No   Fewer than 10 employees
#
#       Dependents                                            DevType Gender  \
# 1            Yes  Database administrator;DevOps specialist;Full-...   Male
# 5             No  Back-end developer;Database administrator;Fron...   Male
# 17           Yes                                 Back-end developer   Male
# 20           Yes  Database administrator;Full-stack developer;Mo...   Male
# 22            No  Back-end developer;Database administrator;Desi...   Male
# ...          ...                                                ...    ...
# 71505        Yes                                Front-end developer   Male
# 71510         No                                 Back-end developer   Male
# 71517         No  Back-end developer;Desktop or enterprise appli...   Male
# 71524         No  Back-end developer;C-suite executive (CEO, CTO...   Male
# 71526         No  Back-end developer;Full-stack developer;Produc...   Male
#
#                JobSatisfaction                 LastNewJob     Salary  ...  \
# 1      Moderately dissatisfied      More than 4 years ago      51000  ...
# 5         Moderately satisfied  Between 2 and 4 years ago      30000  ...
# 17        Moderately satisfied  Between 1 and 2 years ago      32000  ...
# 20          Slightly satisfied  Between 2 and 4 years ago     120000  ...
# 22          Slightly satisfied      More than 4 years ago         25  ...
# ...                        ...                        ...        ...  ...
# 71505      Extremely satisfied       Less than a year ago      85000  ...
# 71510     Moderately satisfied  Between 1 and 2 years ago     140000  ...
# 71517       Slightly satisfied       Less than a year ago      80000  ...
# 71524      Extremely satisfied      More than 4 years ago     165000  ...
# 71526      Extremely satisfied  Between 1 and 2 years ago  80,000.00  ...
#
#                                   LanguageDesireNextYear  \
# 1                                              Go;Python
# 5      C#;Go;Java;JavaScript;Python;SQL;TypeScript;HT...
# 17                               C#;F#;Haskell;SQL;Ocaml
# 20                      C;C++;Go;Python;SQL;Swift;Kotlin
# 22                        C#;JavaScript;PHP;SQL;HTML;CSS
# ...                                                  ...
# 71505     C++;C#;Java;JavaScript;SQL;HTML;CSS;Bash/Shell
# 71510      Java;JavaScript;Python;Ruby;TypeScript;Kotlin
# 71517                    C#;F#;JavaScript;SQL;TypeScript
# 71524                                          Clojure;R
# 71526                                      Python;Kotlin
#
#                                       DatabaseWorkedWith  \
# 1                             Redis;PostgreSQL;Memcached
# 5                                                MongoDB
# 17                                            SQL Server
# 20                               Redis;PostgreSQL;SQLite
# 22                                                 MySQL
# ...                                                  ...
# 71505                           MongoDB;MySQL;PostgreSQL
# 71510  MySQL;PostgreSQL;Amazon DynamoDB;Amazon Redshi...
# 71517  SQL Server;PostgreSQL;Microsoft Azure (Tables,...
# 71524  Redis;SQL Server;PostgreSQL;Microsoft Azure (T...
# 71526  MongoDB;SQL Server;MySQL;PostgreSQL;MariaDB;Am...
#
#                           DatabaseDesireNextYear  \
# 1                                     PostgreSQL
# 5                                     PostgreSQL
# 17     Redis;SQL Server;PostgreSQL;Elasticsearch
# 20       Redis;PostgreSQL;SQLite;Google BigQuery
# 22                              SQL Server;MySQL
# ...                                          ...
# 71505                           MySQL;PostgreSQL
# 71510                            Amazon DynamoDB
# 71517        SQL Server;PostgreSQL;Elasticsearch
# 71524                           Redis;PostgreSQL
# 71526                                  Cassandra
#
#                                       PlatformWorkedWith  \
# 1                                                  Linux
# 5                                                  Linux
# 17                       Linux;Windows Desktop or Server
# 20                 Android;AWS;iOS;Linux;Mac OS;Firebase
# 22                Linux;Mac OS;Windows Desktop or Server
# ...                                                  ...
# 71505                    Android;AWS;iOS;Mac OS;Firebase
# 71510                                Amazon Echo;Android
# 71517        Android;Azure;iOS;Windows Desktop or Server
# 71524  AWS;Azure;Google Cloud Platform/App Engine;Lin...
# 71526                     Android;AWS;iOS;Linux;Firebase
#
#                                   PlatformDesireNextYear  \
# 1                                                  Linux
# 5                                                  Linux
# 17                       Linux;Windows Desktop or Server
# 20     Android;AWS;Google Cloud Platform/App Engine;i...
# 22                Linux;Mac OS;Windows Desktop or Server
# ...                                                  ...
# 71505  Android;Apple Watch or Apple TV;iOS;Mac OS;Ras...
# 71510                                        Amazon Echo
# 71517        Android;Azure;iOS;Windows Desktop or Server
# 71524                                              Linux
# 71526                                        Amazon Echo
#
#                                  FrameworkWorkedWith  \
# 1                                             Django
# 5                                    Angular;Node.js
# 17                                         .NET Core
# 20                                   Angular;Node.js
# 22                                         .NET Core
# ...                                              ...
# 71505                          Angular;Node.js;React
# 71510                           Node.js;React;Spring
# 71517              Angular;.NET Core;Node.js;Xamarin
# 71524  Django;Node.js;React;TensorFlow;Torch/PyTorch
# 71526                              .NET Core;Node.js
#
#                      FrameworkDesireNextYear OperatingSystem  \
# 1                                      React     Linux-based
# 5                                    Node.js     Linux-based
# 17                                 .NET Core         Windows
# 20                Angular;Node.js;TensorFlow           MacOS
# 22                                 .NET Core         Windows
# ...                                      ...             ...
# 71505                          Node.js;React           MacOS
# 71510                                 Spring           MacOS
# 71517      Angular;.NET Core;Node.js;Xamarin         Windows
# 71524  Django;React;TensorFlow;Torch/PyTorch           MacOS
# 71526                                  React           MacOS
#
#             HypotheticalTools1                Age
# 1      A little bit interested  35 - 44 years old
# 5      A little bit interested  18 - 24 years old
# 17       Not at all interested  35 - 44 years old
# 20     A little bit interested  35 - 44 years old
# 22         Somewhat interested  25 - 34 years old
# ...                        ...                ...
# 71505      Somewhat interested  25 - 34 years old
# 71510     Extremely interested  25 - 34 years old
# 71517      Somewhat interested  25 - 34 years old
# 71524    Not at all interested  35 - 44 years old
# 71526     Extremely interested  25 - 34 years old
#
# [16757 rows x 21 columns]

# %%
jd = pd.read_csv("Job Description Dataset/dice_com-job_us_sample.csv")

# %%
resume_subset.isna().sum()
# Out:
# Respondent                     0
# Country                      412
# Student                     3954
# CompanySize                27324
# Dependents                 36259
# DevType                     6757
# Gender                     34386
# JobSatisfaction            29579
# LastNewJob                 19966
# Salary                     48277
# LanguageWorkedWith         20521
# LanguageDesireNextYear     25611
# DatabaseWorkedWith         32585
# DatabaseDesireNextYear     41357
# PlatformWorkedWith         32856
# PlatformDesireNextYear     37502
# FrameworkWorkedWith        47235
# FrameworkDesireNextYear    43637
# OperatingSystem            22676
# HypotheticalTools1         28787
# Age                        34281
# dtype: int64

# %%
resume_subset.describe()
# Out:
#           Respondent
# count   98855.000000
# mean    50822.971635
# std     29321.650410
# min         1.000000
# 25%     25443.500000
# 50%     50823.000000
# 75%     76219.500000
# max    101592.000000

# %%
dataset.columns
# Out:
# Index(['Respondent', 'Hobby', 'OpenSource', 'Country', 'Student', 'Employment',
#        'FormalEducation', 'UndergradMajor', 'CompanySize', 'DevType',
#        ...
#        'Exercise', 'Gender', 'SexualOrientation', 'EducationParents',
#        'RaceEthnicity', 'Age', 'Dependents', 'MilitaryUS', 'SurveyTooLong',
#        'SurveyEasy'],
#       dtype='object', length=129)

# %%
resume_subset= dataset[['Respondent','Country','Student','CompanySize','Dependents','DevType','Gender','JobSatisfaction','LastNewJob','Salary','LanguageWorkedWith','LanguageDesireNextYear','DatabaseWorkedWith','DatabaseDesireNextYear','PlatformWorkedWith','PlatformDesireNextYear','FrameworkWorkedWith','FrameworkDesireNextYear','OperatingSystem','HypotheticalTools1','Age']]
resume_subset
# Out:
#        Respondent             Country         Student  \
# 0               1               Kenya              No
# 1               3      United Kingdom              No
# 2               4       United States              No
# 3               5       United States              No
# 4               7        South Africa  Yes, part-time
# ...           ...                 ...             ...
# 98850      101513       United States             NaN
# 98851      101531               Spain  Yes, full-time
# 98852      101541               India  Yes, full-time
# 98853      101544  Russian Federation              No
# 98854      101548            Cambodia             NaN
#
#                     CompanySize Dependents  \
# 0            20 to 99 employees        Yes
# 1      10,000 or more employees        Yes
# 2            20 to 99 employees        NaN
# 3          100 to 499 employees         No
# 4      10,000 or more employees        Yes
# ...                         ...        ...
# 98850                       NaN        NaN
# 98851                       NaN        NaN
# 98852                       NaN        NaN
# 98853                       NaN        NaN
# 98854                       NaN        NaN
#
#                                                  DevType Gender  \
# 0                                   Full-stack developer   Male
# 1      Database administrator;DevOps specialist;Full-...   Male
# 2               Engineering manager;Full-stack developer    NaN
# 3                                   Full-stack developer   Male
# 4      Data or business analyst;Desktop or enterprise...   Male
# ...                                                  ...    ...
# 98850                                                NaN    NaN
# 98851             Back-end developer;Front-end developer    NaN
# 98852                                                NaN    NaN
# 98853                                                NaN    NaN
# 98854                                                NaN    NaN
#
#                           JobSatisfaction                 LastNewJob  Salary  \
# 0                     Extremely satisfied       Less than a year ago     NaN
# 1                 Moderately dissatisfied      More than 4 years ago   51000
# 2                    Moderately satisfied       Less than a year ago     NaN
# 3      Neither satisfied nor dissatisfied       Less than a year ago     NaN
# 4                      Slightly satisfied  Between 1 and 2 years ago  260000
# ...                                   ...                        ...     ...
# 98850                                 NaN                        NaN     NaN
# 98851                                 NaN                        NaN     NaN
# 98852                                 NaN                        NaN     NaN
# 98853                                 NaN                        NaN     NaN
# 98854                                 NaN                        NaN     NaN
#
#        ...                            LanguageDesireNextYear  \
# 0      ...                        JavaScript;Python;HTML;CSS
# 1      ...                                         Go;Python
# 2      ...                                               NaN
# 3      ...  C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4      ...              Assembly;C;C++;Matlab;SQL;Bash/Shell
# ...    ...                                               ...
# 98850  ...                                               NaN
# 98851  ...                                               NaN
# 98852  ...                                               NaN
# 98853  ...                                               NaN
# 98854  ...                                               NaN
#
#                                       DatabaseWorkedWith  \
# 0      Redis;SQL Server;MySQL;PostgreSQL;Amazon RDS/A...
# 1                             Redis;PostgreSQL;Memcached
# 2                                                    NaN
# 3      SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 4                   SQL Server;PostgreSQL;Oracle;IBM Db2
# ...                                                  ...
# 98850                                                NaN
# 98851                                                NaN
# 98852                                                NaN
# 98853                                                NaN
# 98854                                                NaN
#
#                                   DatabaseDesireNextYear  \
# 0      Redis;SQL Server;MySQL;PostgreSQL;Amazon RDS/A...
# 1                                             PostgreSQL
# 2                                                    NaN
# 3      SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 4                              PostgreSQL;Oracle;IBM Db2
# ...                                                  ...
# 98850                                                NaN
# 98851                                                NaN
# 98852                                                NaN
# 98853                                                NaN
# 98854                                                NaN
#
#                       PlatformWorkedWith             PlatformDesireNextYear  \
# 0               AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                                  Linux                              Linux
# 2                                    NaN                                NaN
# 3                                  Azure                              Azure
# 4      Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
# ...                                  ...                                ...
# 98850                                NaN                                NaN
# 98851                                NaN                                NaN
# 98852                                NaN                                NaN
# 98853                                NaN                                NaN
# 98854                                NaN                                NaN
#
#       FrameworkWorkedWith  FrameworkDesireNextYear OperatingSystem  \
# 0            Django;React             Django;React     Linux-based
# 1                  Django                    React     Linux-based
# 2                     NaN                      NaN             NaN
# 3                     NaN  Angular;.NET Core;React         Windows
# 4                     NaN                      NaN         Windows
# ...                   ...                      ...             ...
# 98850                 NaN                      NaN             NaN
# 98851                 NaN                      NaN             NaN
# 98852                 NaN                      NaN             NaN
# 98853                 NaN                      NaN             NaN
# 98854                 NaN                      NaN             NaN
#
#             HypotheticalTools1                Age
# 0         Extremely interested  25 - 34 years old
# 1      A little bit interested  35 - 44 years old
# 2                          NaN                NaN
# 3          Somewhat interested  35 - 44 years old
# 4         Extremely interested  18 - 24 years old
# ...                        ...                ...
# 98850                      NaN                NaN
# 98851                      NaN                NaN
# 98852                      NaN                NaN
# 98853                      NaN                NaN
# 98854                      NaN                NaN
#
# [98855 rows x 21 columns]

# %%
resume_subset.dtypes
# Out:
# Respondent                  int64
# Country                    object
# Student                    object
# CompanySize                object
# Dependents                 object
# DevType                    object
# Gender                     object
# JobSatisfaction            object
# LastNewJob                 object
# Salary                     object
# LanguageWorkedWith         object
# LanguageDesireNextYear     object
# DatabaseWorkedWith         object
# DatabaseDesireNextYear     object
# PlatformWorkedWith         object
# PlatformDesireNextYear     object
# FrameworkWorkedWith        object
# FrameworkDesireNextYear    object
# OperatingSystem            object
# HypotheticalTools1         object
# Age                        object
# dtype: object

# %%
Resume= resume_subset.dropna()
Resume
# Out:
#        Respondent         Country         Student               CompanySize  \
# 1               3  United Kingdom              No  10,000 or more employees
# 5               8  United Kingdom              No        10 to 19 employees
# 17             27          Sweden              No        10 to 19 employees
# 20             33       Australia              No  1,000 to 4,999 employees
# 22             37  United Kingdom              No        20 to 99 employees
# ...           ...             ...             ...                       ...
# 71505      101560   United States              No  1,000 to 4,999 employees
# 71510      101567       Australia  Yes, full-time  10,000 or more employees
# 71517      101576   United States              No  10,000 or more employees
# 71524      101584   United States  Yes, full-time        20 to 99 employees
# 71526      101587          Canada              No   Fewer than 10 employees
#
#       Dependents                                            DevType Gender  \
# 1            Yes  Database administrator;DevOps specialist;Full-...   Male
# 5             No  Back-end developer;Database administrator;Fron...   Male
# 17           Yes                                 Back-end developer   Male
# 20           Yes  Database administrator;Full-stack developer;Mo...   Male
# 22            No  Back-end developer;Database administrator;Desi...   Male
# ...          ...                                                ...    ...
# 71505        Yes                                Front-end developer   Male
# 71510         No                                 Back-end developer   Male
# 71517         No  Back-end developer;Desktop or enterprise appli...   Male
# 71524         No  Back-end developer;C-suite executive (CEO, CTO...   Male
# 71526         No  Back-end developer;Full-stack developer;Produc...   Male
#
#                JobSatisfaction                 LastNewJob     Salary  ...  \
# 1      Moderately dissatisfied      More than 4 years ago      51000  ...
# 5         Moderately satisfied  Between 2 and 4 years ago      30000  ...
# 17        Moderately satisfied  Between 1 and 2 years ago      32000  ...
# 20          Slightly satisfied  Between 2 and 4 years ago     120000  ...
# 22          Slightly satisfied      More than 4 years ago         25  ...
# ...                        ...                        ...        ...  ...
# 71505      Extremely satisfied       Less than a year ago      85000  ...
# 71510     Moderately satisfied  Between 1 and 2 years ago     140000  ...
# 71517       Slightly satisfied       Less than a year ago      80000  ...
# 71524      Extremely satisfied      More than 4 years ago     165000  ...
# 71526      Extremely satisfied  Between 1 and 2 years ago  80,000.00  ...
#
#                                   LanguageDesireNextYear  \
# 1                                              Go;Python
# 5      C#;Go;Java;JavaScript;Python;SQL;TypeScript;HT...
# 17                               C#;F#;Haskell;SQL;Ocaml
# 20                      C;C++;Go;Python;SQL;Swift;Kotlin
# 22                        C#;JavaScript;PHP;SQL;HTML;CSS
# ...                                                  ...
# 71505     C++;C#;Java;JavaScript;SQL;HTML;CSS;Bash/Shell
# 71510      Java;JavaScript;Python;Ruby;TypeScript;Kotlin
# 71517                    C#;F#;JavaScript;SQL;TypeScript
# 71524                                          Clojure;R
# 71526                                      Python;Kotlin
#
#                                       DatabaseWorkedWith  \
# 1                             Redis;PostgreSQL;Memcached
# 5                                                MongoDB
# 17                                            SQL Server
# 20                               Redis;PostgreSQL;SQLite
# 22                                                 MySQL
# ...                                                  ...
# 71505                           MongoDB;MySQL;PostgreSQL
# 71510  MySQL;PostgreSQL;Amazon DynamoDB;Amazon Redshi...
# 71517  SQL Server;PostgreSQL;Microsoft Azure (Tables,...
# 71524  Redis;SQL Server;PostgreSQL;Microsoft Azure (T...
# 71526  MongoDB;SQL Server;MySQL;PostgreSQL;MariaDB;Am...
#
#                           DatabaseDesireNextYear  \
# 1                                     PostgreSQL
# 5                                     PostgreSQL
# 17     Redis;SQL Server;PostgreSQL;Elasticsearch
# 20       Redis;PostgreSQL;SQLite;Google BigQuery
# 22                              SQL Server;MySQL
# ...                                          ...
# 71505                           MySQL;PostgreSQL
# 71510                            Amazon DynamoDB
# 71517        SQL Server;PostgreSQL;Elasticsearch
# 71524                           Redis;PostgreSQL
# 71526                                  Cassandra
#
#                                       PlatformWorkedWith  \
# 1                                                  Linux
# 5                                                  Linux
# 17                       Linux;Windows Desktop or Server
# 20                 Android;AWS;iOS;Linux;Mac OS;Firebase
# 22                Linux;Mac OS;Windows Desktop or Server
# ...                                                  ...
# 71505                    Android;AWS;iOS;Mac OS;Firebase
# 71510                                Amazon Echo;Android
# 71517        Android;Azure;iOS;Windows Desktop or Server
# 71524  AWS;Azure;Google Cloud Platform/App Engine;Lin...
# 71526                     Android;AWS;iOS;Linux;Firebase
#
#                                   PlatformDesireNextYear  \
# 1                                                  Linux
# 5                                                  Linux
# 17                       Linux;Windows Desktop or Server
# 20     Android;AWS;Google Cloud Platform/App Engine;i...
# 22                Linux;Mac OS;Windows Desktop or Server
# ...                                                  ...
# 71505  Android;Apple Watch or Apple TV;iOS;Mac OS;Ras...
# 71510                                        Amazon Echo
# 71517        Android;Azure;iOS;Windows Desktop or Server
# 71524                                              Linux
# 71526                                        Amazon Echo
#
#                                  FrameworkWorkedWith  \
# 1                                             Django
# 5                                    Angular;Node.js
# 17                                         .NET Core
# 20                                   Angular;Node.js
# 22                                         .NET Core
# ...                                              ...
# 71505                          Angular;Node.js;React
# 71510                           Node.js;React;Spring
# 71517              Angular;.NET Core;Node.js;Xamarin
# 71524  Django;Node.js;React;TensorFlow;Torch/PyTorch
# 71526                              .NET Core;Node.js
#
#                      FrameworkDesireNextYear OperatingSystem  \
# 1                                      React     Linux-based
# 5                                    Node.js     Linux-based
# 17                                 .NET Core         Windows
# 20                Angular;Node.js;TensorFlow           MacOS
# 22                                 .NET Core         Windows
# ...                                      ...             ...
# 71505                          Node.js;React           MacOS
# 71510                                 Spring           MacOS
# 71517      Angular;.NET Core;Node.js;Xamarin         Windows
# 71524  Django;React;TensorFlow;Torch/PyTorch           MacOS
# 71526                                  React           MacOS
#
#             HypotheticalTools1                Age
# 1      A little bit interested  35 - 44 years old
# 5      A little bit interested  18 - 24 years old
# 17       Not at all interested  35 - 44 years old
# 20     A little bit interested  35 - 44 years old
# 22         Somewhat interested  25 - 34 years old
# ...                        ...                ...
# 71505      Somewhat interested  25 - 34 years old
# 71510     Extremely interested  25 - 34 years old
# 71517      Somewhat interested  25 - 34 years old
# 71524    Not at all interested  35 - 44 years old
# 71526     Extremely interested  25 - 34 years old
#
# [16757 rows x 21 columns]

# %%
Resume.hist(bins=60, figsize=(30,20))
# Out:
# array([[<AxesSubplot:title={'center':'Respondent'}>]], dtype=object)

# %%
Resume['DevType'].value_counts()
# Out:
# Full-stack developer                                                                                                                                                                1340
# Back-end developer;Front-end developer;Full-stack developer                                                                                                                         1175
# Back-end developer                                                                                                                                                                  1085
# Back-end developer;Full-stack developer                                                                                                                                              801
# Back-end developer;Front-end developer;Full-stack developer;Mobile developer                                                                                                         377
#                                                                                                                                                                                     ...
# Back-end developer;Data scientist or machine learning specialist;DevOps specialist;Educator or academic researcher;Front-end developer;Full-stack developer;System administrator       1
# Back-end developer;Data scientist or machine learning specialist;Product manager                                                                                                       1
# Back-end developer;Database administrator;Desktop or enterprise applications developer;DevOps specialist;Full-stack developer;Student                                                  1
# Database administrator;Front-end developer;Full-stack developer;System administrator                                                                                                   1
# Back-end developer;C-suite executive (CEO, CTO, etc.);Data scientist or machine learning specialist;Engineering manager;Front-end developer;Full-stack developer;Product manager       1
# Name: DevType, Length: 3034, dtype: int64

# %%
Devtype_value= Resume['DevType'].value_counts()
Resume2= Resume[~Resume['DevType'].isin(Devtype_value[Devtype_value>100].index)]
Resume2
# Out:
#        Respondent         Country         Student               CompanySize  \
# 1               3  United Kingdom              No  10,000 or more employees
# 20             33       Australia              No  1,000 to 4,999 employees
# 22             37  United Kingdom              No        20 to 99 employees
# 30             47          Poland              No        20 to 99 employees
# 37             56         Belgium  Yes, part-time        20 to 99 employees
# ...           ...             ...             ...                       ...
# 71497      101551           India              No   Fewer than 10 employees
# 71502      101557   United States  Yes, full-time  5,000 to 9,999 employees
# 71504      101559           Italy              No      100 to 499 employees
# 71524      101584   United States  Yes, full-time        20 to 99 employees
# 71526      101587          Canada              No   Fewer than 10 employees
#
#       Dependents                                            DevType Gender  \
# 1            Yes  Database administrator;DevOps specialist;Full-...   Male
# 20           Yes  Database administrator;Full-stack developer;Mo...   Male
# 22            No  Back-end developer;Database administrator;Desi...   Male
# 30            No             Back-end developer;Engineering manager   Male
# 37           Yes  Back-end developer;Database administrator;Fron...   Male
# ...          ...                                                ...    ...
# 71497         No  Back-end developer;Front-end developer;Mobile ...   Male
# 71502         No                               QA or test developer   Male
# 71504         No  Front-end developer;Game or graphics developer...   Male
# 71524         No  Back-end developer;C-suite executive (CEO, CTO...   Male
# 71526         No  Back-end developer;Full-stack developer;Produc...   Male
#
#                JobSatisfaction                 LastNewJob     Salary  ...  \
# 1      Moderately dissatisfied      More than 4 years ago      51000  ...
# 20          Slightly satisfied  Between 2 and 4 years ago     120000  ...
# 22          Slightly satisfied      More than 4 years ago         25  ...
# 30          Slightly satisfied       Less than a year ago       8500  ...
# 37       Slightly dissatisfied  Between 2 and 4 years ago       2600  ...
# ...                        ...                        ...        ...  ...
# 71497    Slightly dissatisfied       Less than a year ago       1500  ...
# 71502       Slightly satisfied       Less than a year ago        500  ...
# 71504     Moderately satisfied       Less than a year ago      25000  ...
# 71524      Extremely satisfied      More than 4 years ago     165000  ...
# 71526      Extremely satisfied  Between 1 and 2 years ago  80,000.00  ...
#
#                                   LanguageDesireNextYear  \
# 1                                              Go;Python
# 20                      C;C++;Go;Python;SQL;Swift;Kotlin
# 22                        C#;JavaScript;PHP;SQL;HTML;CSS
# 30                             Erlang;Go;JavaScript;Rust
# 37                 C#;JavaScript;SQL;TypeScript;HTML;CSS
# ...                                                  ...
# 71497                                        Objective-C
# 71502  Groovy;Haskell;Java;JavaScript;Python;HTML;CSS...
# 71504   C;C++;Java;JavaScript;TypeScript;VB.NET;HTML;CSS
# 71524                                          Clojure;R
# 71526                                      Python;Kotlin
#
#                                       DatabaseWorkedWith  \
# 1                             Redis;PostgreSQL;Memcached
# 20                               Redis;PostgreSQL;SQLite
# 22                                                 MySQL
# 30                        MongoDB;Redis;MySQL;PostgreSQL
# 37                                 SQL Server;PostgreSQL
# ...                                                  ...
# 71497                        SQL Server;MySQL;PostgreSQL
# 71502                    MongoDB;MySQL;PostgreSQL;Oracle
# 71504                                   MySQL;PostgreSQL
# 71524  Redis;SQL Server;PostgreSQL;Microsoft Azure (T...
# 71526  MongoDB;SQL Server;MySQL;PostgreSQL;MariaDB;Am...
#
#                                   DatabaseDesireNextYear  \
# 1                                             PostgreSQL
# 20               Redis;PostgreSQL;SQLite;Google BigQuery
# 22                                      SQL Server;MySQL
# 30                               Memcached;Elasticsearch
# 37                                 SQL Server;PostgreSQL
# ...                                                  ...
# 71497  MongoDB;Amazon DynamoDB;Amazon RDS/Aurora;Micr...
# 71502  MongoDB;MySQL;PostgreSQL;SQLite;Microsoft Azur...
# 71504  MongoDB;MySQL;PostgreSQL;SQLite;Microsoft Azur...
# 71524                                   Redis;PostgreSQL
# 71526                                          Cassandra
#
#                                       PlatformWorkedWith  \
# 1                                                  Linux
# 20                 Android;AWS;iOS;Linux;Mac OS;Firebase
# 22                Linux;Mac OS;Windows Desktop or Server
# 30                                                 Linux
# 37                                  Android;Raspberry Pi
# ...                                                  ...
# 71497       Android;Arduino;AWS;Linux;WordPress;Firebase
# 71502            Android;Arduino;ESP8266;Heroku;Firebase
# 71504                          Android;iOS;Windows Phone
# 71524  AWS;Azure;Google Cloud Platform/App Engine;Lin...
# 71526                     Android;AWS;iOS;Linux;Firebase
#
#                                   PlatformDesireNextYear  \
# 1                                                  Linux
# 20     Android;AWS;Google Cloud Platform/App Engine;i...
# 22                Linux;Mac OS;Windows Desktop or Server
# 30                                   Heroku;Raspberry Pi
# 37                                  Android;Raspberry Pi
# ...                                                  ...
# 71497  Google Cloud Platform/App Engine;IBM Cloud or ...
# 71502  Amazon Echo;Android;Arduino;AWS;Azure;ESP8266;...
# 71504  Gaming console;iOS;Raspberry Pi;Windows Deskto...
# 71524                                              Linux
# 71526                                        Amazon Echo
#
#                                  FrameworkWorkedWith  \
# 1                                             Django
# 20                                   Angular;Node.js
# 22                                         .NET Core
# 30                                            Django
# 37                         Angular;.NET Core;Xamarin
# ...                                              ...
# 71497                        Angular;Node.js;Cordova
# 71502                       Node.js;React;TensorFlow
# 71504                                Angular;Cordova
# 71524  Django;Node.js;React;TensorFlow;Torch/PyTorch
# 71526                              .NET Core;Node.js
#
#                        FrameworkDesireNextYear OperatingSystem  \
# 1                                        React     Linux-based
# 20                  Angular;Node.js;TensorFlow           MacOS
# 22                                   .NET Core         Windows
# 30                            React;TensorFlow     Linux-based
# 37     Angular;.NET Core;Node.js;React;Xamarin         Windows
# ...                                        ...             ...
# 71497                      Hadoop;React;Spring     Linux-based
# 71502                            Node.js;React         Windows
# 71504             Hadoop;Node.js;React;Xamarin         Windows
# 71524    Django;React;TensorFlow;Torch/PyTorch           MacOS
# 71526                                    React           MacOS
#
#             HypotheticalTools1                Age
# 1      A little bit interested  35 - 44 years old
# 20     A little bit interested  35 - 44 years old
# 22         Somewhat interested  25 - 34 years old
# 30       Not at all interested  25 - 34 years old
# 37         Somewhat interested  25 - 34 years old
# ...                        ...                ...
# 71497     Extremely interested  18 - 24 years old
# 71502      Somewhat interested  18 - 24 years old
# 71504      Somewhat interested  25 - 34 years old
# 71524    Not at all interested  35 - 44 years old
# 71526     Extremely interested  25 - 34 years old
#
# [9273 rows x 21 columns]

# %%
Resume2['Age'].value_counts()
# Out:
# 25 - 34 years old     4932
# 18 - 24 years old     2011
# 35 - 44 years old     1821
# 45 - 54 years old      401
# 55 - 64 years old       87
# Under 18 years old      19
# 65 years or older        2
# Name: Age, dtype: int64

# %%
Resume2['OperatingSystem'].value_counts()
# Out:
# Windows        4650
# MacOS          2662
# Linux-based    1952
# BSD/Unix          9
# Name: OperatingSystem, dtype: int64

# %%
location= Resume2['Country'].value_counts()
location[location>50].sum()
# Out:
# 8138

# %%
Resume3= Resume2[Resume2['Country'].isin(location[location>50].index)]
Resume3
# Out:
#        Respondent         Country         Student               CompanySize  \
# 1               3  United Kingdom              No  10,000 or more employees
# 20             33       Australia              No  1,000 to 4,999 employees
# 22             37  United Kingdom              No        20 to 99 employees
# 30             47          Poland              No        20 to 99 employees
# 37             56         Belgium  Yes, part-time        20 to 99 employees
# ...           ...             ...             ...                       ...
# 71497      101551           India              No   Fewer than 10 employees
# 71502      101557   United States  Yes, full-time  5,000 to 9,999 employees
# 71504      101559           Italy              No      100 to 499 employees
# 71524      101584   United States  Yes, full-time        20 to 99 employees
# 71526      101587          Canada              No   Fewer than 10 employees
#
#       Dependents                                            DevType Gender  \
# 1            Yes  Database administrator;DevOps specialist;Full-...   Male
# 20           Yes  Database administrator;Full-stack developer;Mo...   Male
# 22            No  Back-end developer;Database administrator;Desi...   Male
# 30            No             Back-end developer;Engineering manager   Male
# 37           Yes  Back-end developer;Database administrator;Fron...   Male
# ...          ...                                                ...    ...
# 71497         No  Back-end developer;Front-end developer;Mobile ...   Male
# 71502         No                               QA or test developer   Male
# 71504         No  Front-end developer;Game or graphics developer...   Male
# 71524         No  Back-end developer;C-suite executive (CEO, CTO...   Male
# 71526         No  Back-end developer;Full-stack developer;Produc...   Male
#
#                JobSatisfaction                 LastNewJob     Salary  ...  \
# 1      Moderately dissatisfied      More than 4 years ago      51000  ...
# 20          Slightly satisfied  Between 2 and 4 years ago     120000  ...
# 22          Slightly satisfied      More than 4 years ago         25  ...
# 30          Slightly satisfied       Less than a year ago       8500  ...
# 37       Slightly dissatisfied  Between 2 and 4 years ago       2600  ...
# ...                        ...                        ...        ...  ...
# 71497    Slightly dissatisfied       Less than a year ago       1500  ...
# 71502       Slightly satisfied       Less than a year ago        500  ...
# 71504     Moderately satisfied       Less than a year ago      25000  ...
# 71524      Extremely satisfied      More than 4 years ago     165000  ...
# 71526      Extremely satisfied  Between 1 and 2 years ago  80,000.00  ...
#
#                                   LanguageDesireNextYear  \
# 1                                              Go;Python
# 20                      C;C++;Go;Python;SQL;Swift;Kotlin
# 22                        C#;JavaScript;PHP;SQL;HTML;CSS
# 30                             Erlang;Go;JavaScript;Rust
# 37                 C#;JavaScript;SQL;TypeScript;HTML;CSS
# ...                                                  ...
# 71497                                        Objective-C
# 71502  Groovy;Haskell;Java;JavaScript;Python;HTML;CSS...
# 71504   C;C++;Java;JavaScript;TypeScript;VB.NET;HTML;CSS
# 71524                                          Clojure;R
# 71526                                      Python;Kotlin
#
#                                       DatabaseWorkedWith  \
# 1                             Redis;PostgreSQL;Memcached
# 20                               Redis;PostgreSQL;SQLite
# 22                                                 MySQL
# 30                        MongoDB;Redis;MySQL;PostgreSQL
# 37                                 SQL Server;PostgreSQL
# ...                                                  ...
# 71497                        SQL Server;MySQL;PostgreSQL
# 71502                    MongoDB;MySQL;PostgreSQL;Oracle
# 71504                                   MySQL;PostgreSQL
# 71524  Redis;SQL Server;PostgreSQL;Microsoft Azure (T...
# 71526  MongoDB;SQL Server;MySQL;PostgreSQL;MariaDB;Am...
#
#                                   DatabaseDesireNextYear  \
# 1                                             PostgreSQL
# 20               Redis;PostgreSQL;SQLite;Google BigQuery
# 22                                      SQL Server;MySQL
# 30                               Memcached;Elasticsearch
# 37                                 SQL Server;PostgreSQL
# ...                                                  ...
# 71497  MongoDB;Amazon DynamoDB;Amazon RDS/Aurora;Micr...
# 71502  MongoDB;MySQL;PostgreSQL;SQLite;Microsoft Azur...
# 71504  MongoDB;MySQL;PostgreSQL;SQLite;Microsoft Azur...
# 71524                                   Redis;PostgreSQL
# 71526                                          Cassandra
#
#                                       PlatformWorkedWith  \
# 1                                                  Linux
# 20                 Android;AWS;iOS;Linux;Mac OS;Firebase
# 22                Linux;Mac OS;Windows Desktop or Server
# 30                                                 Linux
# 37                                  Android;Raspberry Pi
# ...                                                  ...
# 71497       Android;Arduino;AWS;Linux;WordPress;Firebase
# 71502            Android;Arduino;ESP8266;Heroku;Firebase
# 71504                          Android;iOS;Windows Phone
# 71524  AWS;Azure;Google Cloud Platform/App Engine;Lin...
# 71526                     Android;AWS;iOS;Linux;Firebase
#
#                                   PlatformDesireNextYear  \
# 1                                                  Linux
# 20     Android;AWS;Google Cloud Platform/App Engine;i...
# 22                Linux;Mac OS;Windows Desktop or Server
# 30                                   Heroku;Raspberry Pi
# 37                                  Android;Raspberry Pi
# ...                                                  ...
# 71497  Google Cloud Platform/App Engine;IBM Cloud or ...
# 71502  Amazon Echo;Android;Arduino;AWS;Azure;ESP8266;...
# 71504  Gaming console;iOS;Raspberry Pi;Windows Deskto...
# 71524                                              Linux
# 71526                                        Amazon Echo
#
#                                  FrameworkWorkedWith  \
# 1                                             Django
# 20                                   Angular;Node.js
# 22                                         .NET Core
# 30                                            Django
# 37                         Angular;.NET Core;Xamarin
# ...                                              ...
# 71497                        Angular;Node.js;Cordova
# 71502                       Node.js;React;TensorFlow
# 71504                                Angular;Cordova
# 71524  Django;Node.js;React;TensorFlow;Torch/PyTorch
# 71526                              .NET Core;Node.js
#
#                        FrameworkDesireNextYear OperatingSystem  \
# 1                                        React     Linux-based
# 20                  Angular;Node.js;TensorFlow           MacOS
# 22                                   .NET Core         Windows
# 30                            React;TensorFlow     Linux-based
# 37     Angular;.NET Core;Node.js;React;Xamarin         Windows
# ...                                        ...             ...
# 71497                      Hadoop;React;Spring     Linux-based
# 71502                            Node.js;React         Windows
# 71504             Hadoop;Node.js;React;Xamarin         Windows
# 71524    Django;React;TensorFlow;Torch/PyTorch           MacOS
# 71526                                    React           MacOS
#
#             HypotheticalTools1                Age
# 1      A little bit interested  35 - 44 years old
# 20     A little bit interested  35 - 44 years old
# 22         Somewhat interested  25 - 34 years old
# 30       Not at all interested  25 - 34 years old
# 37         Somewhat interested  25 - 34 years old
# ...                        ...                ...
# 71497     Extremely interested  18 - 24 years old
# 71502      Somewhat interested  18 - 24 years old
# 71504      Somewhat interested  25 - 34 years old
# 71524    Not at all interested  35 - 44 years old
# 71526     Extremely interested  25 - 34 years old
#
# [8138 rows x 21 columns]

# %%
gender_value=Resume3.groupby('Gender')['Gender'].agg('count').sort_values(ascending=False)
print(gender_value)
# Out:
# Gender
# Male                                                                         7703
# Female                                                                        316
# Non-binary, genderqueer, or gender non-conforming                              32
# Male;Non-binary, genderqueer, or gender non-conforming                         22
# Female;Transgender                                                             19
# Transgender                                                                    11
# Female;Male                                                                     8
# Transgender;Non-binary, genderqueer, or gender non-conforming                   8
# Female;Non-binary, genderqueer, or gender non-conforming                        7
# Male;Transgender                                                                5
# Female;Male;Transgender                                                         3
# Female;Male;Transgender;Non-binary, genderqueer, or gender non-conforming       2
# Female;Male;Non-binary, genderqueer, or gender non-conforming                   1
# Female;Transgender;Non-binary, genderqueer, or gender non-conforming            1
# Name: Gender, dtype: int64

# %% [markdown]
# // note to muskan
# rather hme male,female and other aise 3 categories banani h
# so we should be replacing every value in row with these 3 values

# %%
gender_less_than_40= gender_value[gender_value<40]
gender_less_than_40
# Out:
# Gender
# Non-binary, genderqueer, or gender non-conforming                            32
# Male;Non-binary, genderqueer, or gender non-conforming                       22
# Female;Transgender                                                           19
# Transgender                                                                  11
# Female;Male                                                                   8
# Transgender;Non-binary, genderqueer, or gender non-conforming                 8
# Female;Non-binary, genderqueer, or gender non-conforming                      7
# Male;Transgender                                                              5
# Female;Male;Transgender                                                       3
# Female;Male;Transgender;Non-binary, genderqueer, or gender non-conforming     2
# Female;Male;Non-binary, genderqueer, or gender non-conforming                 1
# Female;Transgender;Non-binary, genderqueer, or gender non-conforming          1
# Name: Gender, dtype: int64

# %%
Resume3.Gender= Resume3.Gender.apply(lambda x: 'other' if x in gender_less_than_40 else x)
len(Resume3.Gender.unique())
# Out:
# c:\users\hp\appdata\local\programs\python\python310\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 3

# %%
index_no = Resume3.columns.get_loc('LanguageWorkedWith')
index_no
# Out:
# 10

# %%
Resume3['LanguageWorkedWith'] = Resume3['LanguageWorkedWith'].str.replace(';',',')
Resume3['PlatformWorkedWith'] = Resume3['PlatformWorkedWith'].str.replace(';',',')
Resume3['DatabaseWorkedWith'] = Resume3['DatabaseWorkedWith'].str.replace(';',',')
Resume3['FrameworkWorkedWith'] = Resume3['FrameworkWorkedWith'].str.replace(';',',')
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_7420/2015081233.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Resume3['LanguageWorkedWith'] = Resume3['LanguageWorkedWith'].str.replace(';',',')
# C:\Users\hp\AppData\Local\Temp/ipykernel_7420/2015081233.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Resume3['PlatformWorkedWith'] = Resume3['PlatformWorkedWith'].str.replace(';',',')
# C:\Users\hp\AppData\Local\Temp/ipykernel_7420/2015081233.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Resume3['DatabaseWorkedWith'] = Resume3['DatabaseWorkedWith'].str.replace(';',',')
# C:\Users\hp\AppData\Local\Temp/ipykernel_7420/2015081233.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Resume3['FrameworkWorkedWith'] = Resume3['FrameworkWorkedWith'].str.replace(';',',')

# %%
Resume3['skills'] = Resume3[[Resume3.columns[10],Resume3.columns[12],Resume3.columns[14],Resume3.columns[16]]].values.tolist()
Resume3['skills']
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_7420/1684885520.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Resume3['skills'] = Resume3[[Resume3.columns[10],Resume3.columns[12],Resume3.columns[14],Resume3.columns[16]]].values.tolist()
# 1        [JavaScript,Python,Bash/Shell, Redis,PostgreSQ...
# 20       [C,C++,Go,Python,SQL,Swift, Redis,PostgreSQL,S...
# 22       [C#,JavaScript,PHP,SQL,HTML,CSS, MySQL, Linux,...
# 30       [Python,SQL,HTML,Bash/Shell, MongoDB,Redis,MyS...
# 37       [C#,Java,JavaScript,PHP,SQL,TypeScript,HTML,CS...
#                                ...
# 71497    [C,C++,C#,Java,JavaScript,Matlab,Perl,PHP,Pyth...
# 71502    [C++,Haskell,Java,JavaScript,Python,HTML,CSS,B...
# 71504    [C#,Java,JavaScript,Matlab,HTML,CSS, MySQL,Pos...
# 71524    [C#,Clojure,Go,Java,JavaScript,PHP,R,SQL,HTML,...
# 71526    [C#,Go,Java,JavaScript,PHP,SQL,Swift,HTML,CSS,...
# Name: skills, Length: 8138, dtype: object

# %%
Resume3.iloc[0]['skills']
# Out:
# ['JavaScript,Python,Bash/Shell',
#  'Redis,PostgreSQL,Memcached',
#  'Linux',
#  'Django']

# %%
for index,data in Resume3.iterrows():
    arryOfSkills=data['skills']
    for skillStr in arryOfSkills:
        megaskillslist=[]
        splitEachStr=skillStr.split(',')
        megaskillslist.append(splitEachStr)
    print(megaskillslist)
#         for i in range (len(megaskillslist)):
#             megaskillslist[i]= megaskillslist[i].lower()
#         print(megaskillslist)
#     unique_list = (list(set(megaskillslist)))
#     print(unique_list)
#         Resume3.at[index,'skills']=unique_list
# Resume3.iloc[0]['skills']
# Out:
# ['Django']
# ['Angular', 'Node.js']
# ['.NET Core']
# ['Django']
# ['Angular', '.NET Core', 'Xamarin']
# ['Spring']
# ['Angular', 'Node.js', 'React', 'Cordova']
# ['Django']
# ['Django', 'Hadoop']
# ['Django']
# ['.NET Core', 'Xamarin']
# ['Cordova']
# ['.NET Core', 'Node.js']
# ['Spring']
# ['Node.js', 'TensorFlow']
# ['Node.js']
# ['Angular', '.NET Core', 'Xamarin']
# ['Django']
# ['Node.js', 'React']
# ['.NET Core']
# ['.NET Core', 'Xamarin']
# ['Hadoop', 'Node.js', 'React', 'Spark']
# ['.NET Core']
# ['.NET Core']
# ['Angular', 'Node.js', 'Xamarin']
# ['Angular', 'Node.js', 'React']
# ['TensorFlow']
# ['.NET Core', 'Django', 'React']
# ['Angular', '.NET Core', 'Node.js']
# ['Node.js', 'React']
# ['Node.js', 'React']
# ['Spring']
# ['Angular', '.NET Core']
# ['Node.js']
# ['Angular', '.NET Core', 'Node.js']
# ['Django', 'Hadoop', 'TensorFlow', 'Torch/PyTorch']
# ['Angular', 'Django', 'Node.js', 'React']
# ['.NET Core', 'Django', 'Spark']
# ['Node.js']
# ['Node.js', 'React']
# ['Angular', 'Django']
# ['Django']
# ['Node.js']
# ['Node.js']
# ['Angular', 'Node.js']
# ['Spring']
# ['Angular', 'Node.js']
# ['.NET Core', 'Django']
# ['Angular', '.NET Core', 'Node.js', 'Xamarin']
# ['Angular', 'Node.js', 'React', 'Cordova', 'Spring']
# ['Django', 'Hadoop']
# ['.NET Core']
# ['Cordova']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['Angular', 'Cordova']
# ['.NET Core']
# ['.NET Core']
# ['Node.js', 'Spark', 'Spring', 'TensorFlow']
# ['Angular', 'Node.js', 'React', 'Spring']
# ['TensorFlow']
# ['Django', 'Spring']
# ['Angular', 'Node.js']
# ['.NET Core', 'Xamarin']
# ['TensorFlow']
# ['Node.js', 'React']
# ['Angular', '.NET Core', 'React']
# ['Angular', '.NET Core', 'Node.js']
# ['Spark']
# ['Cordova']
# ['.NET Core', 'Spring']
# ['Spring']
# ['.NET Core', 'Node.js', 'React']
# ['Torch/PyTorch']
# ['.NET Core']
# ['Node.js', 'Spring']
# ['.NET Core', 'Node.js']
# ['.NET Core']
# ['Node.js', 'React']
# ['Angular', 'Node.js', 'Cordova', 'TensorFlow']
# ['Node.js', 'React']
# ['Angular', '.NET Core']
# ['.NET Core']
# ['Django', 'TensorFlow']
# ['.NET Core']
# ['React']
# ['.NET Core', 'Node.js', 'React']
# ['TensorFlow']
# ['Angular']
# ['Node.js']
# ['Angular', '.NET Core', 'Node.js']
# ['TensorFlow']
# ['Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js', 'Cordova']
# ['Node.js', 'Xamarin']
# ['Angular', 'Spring']
# ['Angular', 'Node.js', 'React']
# ['.NET Core']
# ['Django', 'Node.js', 'React']
# ['.NET Core', 'Node.js']
# ['.NET Core', 'Node.js', 'React']
# ['Angular', 'Node.js', 'React']
# ['.NET Core', 'Xamarin']
# ['Django', 'React']
# ['.NET Core', 'Node.js']
# ['.NET Core']
# ['Angular']
# ['React']
# ['.NET Core', 'Node.js', 'React', 'Cordova', 'Xamarin']
# ['Spring']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', 'Node.js', 'Spring']
# ['Spring']
# ['Spring']
# ['Node.js']
# ['Django', 'Node.js', 'React']
# ['.NET Core']
# ['Angular', 'Node.js', 'React', 'Spring']
# ['Angular', 'Node.js']
# ['Angular', '.NET Core', 'Hadoop', 'Node.js', 'Spark', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js']
# ['Spring']
# ['Angular', 'Django', 'Node.js', 'React', 'TensorFlow']
# ['.NET Core']
# ['Node.js']
# ['Angular', 'Spring']
# ['Django']
# ['Angular', 'Spring']
# ['.NET Core', 'Node.js', 'Cordova']
# ['React']
# ['Node.js']
# ['.NET Core']
# ['Angular', 'Spring']
# ['Angular', '.NET Core', 'Node.js', 'Cordova', 'Xamarin']
# ['.NET Core']
# ['Node.js', 'Spring']
# ['Angular', '.NET Core', 'React']
# ['React']
# ['Angular', 'Node.js', 'React']
# ['React']
# ['Angular', 'Node.js']
# ['Angular', '.NET Core', 'Node.js', 'Cordova']
# ['Node.js', 'React']
# ['Angular', 'Node.js', 'React', 'Cordova']
# ['Angular', 'Node.js']
# ['Angular']
# ['Node.js']
# ['Angular', 'Django', 'Hadoop', 'Node.js', 'React', 'Spark']
# ['Angular', 'Node.js', 'Cordova', 'TensorFlow', 'Torch/PyTorch']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Cordova', 'Xamarin']
# ['.NET Core', 'Django', 'Node.js', 'TensorFlow']
# ['.NET Core']
# ['Django']
# ['Node.js']
# ['.NET Core', 'Node.js']
# ['.NET Core', 'Node.js', 'React']
# ['Node.js', 'Cordova']
# ['Angular', 'Node.js']
# ['.NET Core']
# ['Spring']
# ['Angular', 'Node.js']
# ['Node.js']
# ['Spring']
# ['.NET Core', 'React']
# ['Angular', '.NET Core', 'Django', 'Node.js', 'React', 'TensorFlow']
# ['React', 'Spring']
# ['Angular', '.NET Core']
# ['Spring']
# ['Angular', 'Node.js']
# ['Django', 'Node.js']
# ['Angular', 'Node.js', 'Cordova']
# ['.NET Core']
# ['Spring']
# ['Angular', 'Node.js', 'Spring']
# ['Spring']
# ['Spring']
# ['Hadoop', 'Spring']
# ['Xamarin']
# ['Hadoop', 'Spark']
# ['.NET Core', 'Node.js', 'Xamarin']
# ['Node.js']
# ['Django', 'Node.js']
# ['.NET Core', 'TensorFlow']
# ['Angular', 'Node.js', 'React']
# ['Angular', 'Django', 'Node.js', 'React']
# ['.NET Core']
# ['Angular', 'Node.js']
# ['Angular']
# ['Angular', '.NET Core']
# ['.NET Core', 'Spring']
# ['Spring']
# ['Angular', '.NET Core', 'Node.js', 'Spark', 'Cordova', 'Spring']
# ['Django', 'Node.js', 'React']
# ['Node.js', 'Spring']
# ['Angular', 'Node.js', 'Cordova']
# ['Angular', 'Node.js', 'Cordova']
# ['.NET Core']
# ['Hadoop', 'Spark']
# ['Angular', 'Hadoop', 'Node.js', 'Cordova']
# ['Angular', 'React']
# ['Angular', 'Node.js', 'Spring']
# ['.NET Core']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Xamarin', 'TensorFlow']
# ['Angular', '.NET Core', 'Cordova']
# ['Angular', '.NET Core']
# ['React', 'Spring']
# ['.NET Core', 'Node.js', 'React']
# ['Django', 'Node.js', 'React']
# ['Angular', 'Node.js']
# ['.NET Core', 'Xamarin', 'TensorFlow']
# ['Django']
# ['Angular', '.NET Core']
# ['.NET Core', 'Hadoop', 'Spark']
# ['Node.js', 'TensorFlow']
# ['Angular', 'Node.js', 'React', 'Spring']
# ['Angular', 'Django', 'Node.js']
# ['Node.js', 'React']
# ['Node.js', 'React']
# ['.NET Core', 'React']
# ['Django']
# ['Django', 'Node.js', 'React']
# ['Django']
# ['Cordova']
# ['Django']
# ['Angular', 'Spring']
# ['.NET Core']
# ['.NET Core', 'Django', 'Node.js']
# ['React']
# ['Spring']
# ['.NET Core']
# ['Angular', '.NET Core', 'React']
# ['.NET Core', 'Node.js', 'React']
# ['Django', 'React', 'TensorFlow']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core', 'Node.js']
# ['React']
# ['Node.js', 'TensorFlow']
# ['Hadoop', 'Spark']
# ['Node.js']
# ['Django', 'Node.js', 'React']
# ['Angular', 'Django', 'Node.js', 'React']
# ['Node.js']
# ['.NET Core', 'Node.js']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Cordova']
# ['Django']
# ['.NET Core']
# ['Angular', '.NET Core']
# ['Angular', '.NET Core']
# ['Angular', 'Node.js', 'React']
# ['Django', 'Node.js']
# ['.NET Core']
# ['.NET Core']
# ['Django', 'TensorFlow']
# ['.NET Core', 'Node.js', 'Xamarin']
# ['Node.js', 'React']
# ['Node.js']
# ['Angular', '.NET Core']
# ['.NET Core', 'Node.js', 'React']
# ['Angular']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular']
# ['.NET Core', 'Node.js', 'React', 'Cordova', 'Xamarin', 'TensorFlow']
# ['Django', 'Node.js', 'React']
# ['.NET Core']
# ['Django', 'Node.js', 'React', 'Spark', 'TensorFlow']
# ['Node.js']
# ['.NET Core', 'Node.js', 'Xamarin', 'TensorFlow', 'Torch/PyTorch']
# ['Angular', '.NET Core']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', 'Node.js', 'TensorFlow']
# ['Angular', 'Node.js', 'Cordova']
# ['.NET Core', 'Node.js']
# ['Xamarin']
# ['Node.js', 'React']
# ['Angular']
# ['Angular', 'Django']
# ['.NET Core']
# ['.NET Core', 'Xamarin']
# ['.NET Core', 'Hadoop']
# ['Angular']
# ['Angular', 'Node.js', 'React']
# ['Angular', 'Spring']
# ['Spark']
# ['.NET Core', 'React']
# ['Angular', '.NET Core', 'Django', 'React', 'Spark', 'Cordova']
# ['.NET Core', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', 'Node.js']
# ['Spring', 'TensorFlow', 'Torch/PyTorch']
# ['Angular', 'Node.js']
# ['Node.js', 'React']
# ['Angular', 'Node.js', 'React', 'Spark', 'TensorFlow']
# ['Angular', 'Node.js', 'React', 'Spring']
# ['Node.js']
# ['Angular', '.NET Core']
# ['.NET Core']
# ['React']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['.NET Core', 'Node.js', 'Spark']
# ['Node.js', 'React', 'Spring']
# ['.NET Core', 'Node.js']
# ['Angular', 'Node.js']
# ['Angular', '.NET Core']
# ['Hadoop', 'Spark', 'Spring', 'TensorFlow']
# ['.NET Core', 'Node.js']
# ['.NET Core', 'Node.js']
# ['Node.js', 'Cordova']
# ['Node.js']
# ['Angular', 'Spring']
# ['.NET Core']
# ['Django', 'Node.js', 'React']
# ['.NET Core']
# ['Cordova']
# ['.NET Core']
# ['Node.js', 'Spring']
# ['.NET Core']
# ['Hadoop', 'Node.js', 'Spark', 'TensorFlow', 'Torch/PyTorch']
# ['Angular', 'Node.js']
# ['Django']
# ['Angular', 'Node.js', 'Cordova']
# ['Angular', 'React']
# ['Angular', '.NET Core', 'Django', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Xamarin']
# ['Hadoop', 'Spark']
# ['Django', 'Node.js']
# ['.NET Core', 'Xamarin']
# ['Angular', 'Spring']
# ['.NET Core']
# ['Spring']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Xamarin']
# ['Node.js', 'Spring']
# ['Django']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Xamarin']
# ['TensorFlow', 'Torch/PyTorch']
# ['React']
# ['React']
# ['.NET Core', 'React', 'Spring']
# ['Node.js', 'Spring']
# ['Spring']
# ['Angular', 'Node.js']
# ['.NET Core', 'Node.js']
# ['Django', 'Spark', 'Spring']
# ['Angular', '.NET Core', 'Node.js', 'Cordova']
# ['Angular', 'Node.js', 'React']
# ['Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Cordova']
# ['Torch/PyTorch']
# ['Angular']
# ['Node.js', 'React']
# ['Angular', '.NET Core']
# ['Node.js']
# ['Angular', '.NET Core', 'Xamarin']
# ['Angular']
# ['Django', 'Node.js']
# ['Angular', 'Cordova']
# ['Angular', 'Node.js']
# ['Angular', 'Django', 'Node.js', 'React']
# ['React', 'TensorFlow']
# ['Node.js']
# ['.NET Core']
# ['.NET Core', 'React']
# ['Node.js']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js', 'Cordova', 'Xamarin']
# ['Node.js', 'React']
# ['Django', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Xamarin']
# ['Angular', 'Node.js']
# ['.NET Core']
# ['Django']
# ['Node.js', 'React']
# ['Node.js', 'React']
# ['Angular', 'Django', 'Node.js', 'Cordova']
# ['Angular']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', 'Xamarin']
# ['Angular', 'Spring']
# ['Angular', 'Node.js', 'Cordova']
# ['React']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core', 'Hadoop', 'TensorFlow', 'Torch/PyTorch']
# ['Angular', 'Node.js', 'React']
# ['Angular', 'Node.js', 'Cordova']
# ['Angular', '.NET Core']
# ['Angular', 'React', 'Spring']
# ['.NET Core', 'Xamarin']
# ['Spring']
# ['Angular', 'Hadoop', 'Spark']
# ['Angular', '.NET Core', 'Node.js']
# ['Node.js', 'Torch/PyTorch']
# ['Node.js']
# ['.NET Core', 'Node.js']
# ['.NET Core']
# ['Django']
# ['Node.js']
# ['.NET Core', 'Xamarin']
# ['Node.js', 'React', 'Xamarin', 'Spring']
# ['Node.js']
# ['Angular', 'Node.js', 'Spring']
# ['Django']
# ['Angular', 'Node.js', 'Spring']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Spring']
# ['Angular']
# ['.NET Core']
# ['Angular']
# ['Hadoop', 'Spark']
# ['Node.js', 'Spark']
# ['Angular', 'React']
# ['Angular', 'Node.js']
# ['.NET Core', 'React']
# ['Angular', 'Spring']
# ['.NET Core', 'Node.js']
# ['Angular', '.NET Core']
# ['Node.js']
# ['Angular', 'Spring']
# ['Angular', '.NET Core']
# ['Angular', '.NET Core', 'Node.js', 'Cordova', 'Xamarin']
# ['Spring']
# ['Node.js', 'React']
# ['Spring']
# ['Angular']
# ['Angular', 'Node.js', 'React', 'Cordova']
# ['.NET Core', 'Node.js']
# ['Hadoop']
# ['React']
# ['Angular', '.NET Core']
# ['React']
# ['Spring']
# ['Angular', 'Node.js', 'Xamarin']
# ['.NET Core', 'Node.js', 'Xamarin']
# ['Node.js', 'Spring']
# ['Angular', 'Node.js', 'Cordova', 'Spring']
# ['Spring']
# ['Angular', '.NET Core', 'Node.js']
# ['Spring']
# ['Node.js', 'React']
# ['React']
# ['.NET Core']
# ['Angular', 'Node.js', 'React']
# ['.NET Core', 'Node.js']
# ['Spring']
# ['.NET Core', 'Node.js']
# ['Node.js', 'React', 'Spark']
# ['.NET Core', 'Xamarin']
# ['.NET Core']
# ['.NET Core', 'React']
# ['Angular', 'Node.js']
# ['.NET Core', 'Node.js', 'React']
# ['Node.js', 'React', 'Xamarin']
# ['Node.js', 'React']
# ['Angular']
# ['.NET Core', 'Django']
# ['.NET Core', 'Node.js', 'Xamarin']
# ['Node.js']
# ['Angular', '.NET Core', 'Django', 'Node.js', 'React']
# ['.NET Core', 'TensorFlow', 'Torch/PyTorch']
# ['.NET Core', 'Node.js', 'Xamarin']
# ['TensorFlow']
# ['Django', 'Hadoop', 'Node.js', 'Spark']
# ['Angular', 'Node.js', 'Cordova']
# ['.NET Core', 'Node.js']
# ['Angular', 'Node.js']
# ['Node.js', 'React']
# ['Django', 'React', 'Spark']
# ['Angular', '.NET Core', 'Django', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js', 'Cordova']
# ['Angular', 'Node.js']
# ['Angular', 'Node.js', 'React']
# ['Angular', 'Node.js']
# ['Node.js', 'React']
# ['.NET Core']
# ['Node.js', 'React', 'Cordova']
# ['Angular', '.NET Core']
# ['.NET Core', 'Xamarin']
# ['Django']
# ['Angular', '.NET Core', 'Node.js', 'Cordova']
# ['React']
# ['.NET Core', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', '.NET Core', 'Node.js', 'Spring', 'TensorFlow']
# ['Spring']
# ['Angular']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['.NET Core', 'Node.js', 'React']
# ['Angular', 'Node.js', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js', 'Xamarin']
# ['.NET Core']
# ['Angular', 'Node.js', 'Cordova']
# ['.NET Core', 'Node.js', 'Xamarin']
# ['.NET Core']
# ['Angular', 'Node.js', 'Spring']
# ['Hadoop', 'Spark', 'TensorFlow']
# ['Node.js', 'React', 'TensorFlow']
# ['Angular', '.NET Core', 'Cordova']
# ['Django', 'Node.js']
# ['.NET Core', 'Node.js', 'Xamarin']
# ['.NET Core', 'Xamarin']
# ['Angular', 'Node.js', 'React', 'Spring']
# ['.NET Core']
# ['Node.js', 'Spark', 'Cordova', 'TensorFlow']
# ['Django', 'Node.js', 'Cordova']
# ['.NET Core']
# ['Angular', 'Node.js', 'React']
# ['Django']
# ['Spring']
# ['.NET Core']
# ['Node.js', 'React']
# ['TensorFlow']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core', 'Django', 'TensorFlow']
# ['.NET Core']
# ['.NET Core', 'React']
# ['Angular', 'Node.js', 'React']
# ['Angular']
# ['Node.js']
# ['Angular', 'Node.js', 'React', 'TensorFlow', 'Torch/PyTorch']
# ['Angular', 'Django', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Django', 'Node.js', 'React', 'Spring']
# ['.NET Core', 'Cordova', 'Xamarin']
# ['Xamarin']
# ['.NET Core']
# ['Angular', '.NET Core', 'Node.js', 'Cordova', 'Spring']
# ['Node.js']
# ['Spring']
# ['.NET Core', 'Node.js']
# ['.NET Core', 'Xamarin']
# ['Hadoop', 'Spark']
# ['Node.js', 'React']
# ['Spring']
# ['Angular', 'Node.js', 'Spring']
# ['React']
# ['Angular', 'Node.js', 'React']
# ['Angular', 'Django']
# ['Node.js', 'React']
# ['Angular', 'Node.js']
# ['Angular', 'Node.js', 'React']
# ['.NET Core']
# ['.NET Core', 'Xamarin']
# ['Node.js', 'React']
# ['Angular', 'Spark', 'TensorFlow']
# ['Django', 'Node.js']
# ['Node.js', 'Spring']
# ['Angular', 'Cordova', 'Xamarin']
# ['.NET Core', 'Xamarin']
# ['.NET Core']
# ['Django', 'Hadoop', 'Spring']
# ['.NET Core']
# ['Angular', 'Django', 'Node.js', 'React', 'Spring']
# ['Node.js', 'Spring']
# ['Angular', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Spring']
# ['.NET Core']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['.NET Core']
# ['Django', 'Node.js', 'React']
# ['.NET Core']
# ['Node.js']
# ['Spring']
# ['Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js', 'Cordova']
# ['.NET Core']
# ['Node.js']
# ['Angular', '.NET Core', 'Django', 'Node.js', 'React', 'Xamarin', 'TensorFlow']
# ['Node.js']
# ['Node.js', 'Cordova', 'Spring']
# ['Spring']
# ['Node.js', 'React']
# ['.NET Core', 'React']
# ['Node.js', 'React']
# ['Angular', 'Node.js', 'React']
# ['Angular', 'Node.js']
# ['Spring']
# ['.NET Core']
# ['Angular']
# ['Spring']
# ['Node.js', 'Xamarin']
# ['Angular', 'Node.js', 'Cordova']
# ['.NET Core']
# ['Node.js', 'React']
# ['.NET Core']
# ['.NET Core', 'Node.js', 'React', 'Spring', 'TensorFlow']
# ['TensorFlow']
# ['Node.js', 'Spring']
# ['React']
# ['Xamarin']
# ['Angular', 'Django', 'Node.js', 'React', 'Cordova']
# ['TensorFlow']
# ['Angular', 'Django', 'Node.js']
# ['Spring']
# ['Node.js', 'React', 'Spring']
# ['Angular', 'Spring']
# ['.NET Core', 'Node.js']
# ['Hadoop', 'React', 'Spark']
# ['React', 'Spring']
# ['.NET Core', 'Node.js']
# ['TensorFlow']
# ['Node.js']
# ['.NET Core', 'Xamarin']
# ['Angular', 'Cordova']
# ['Node.js']
# ['Angular', 'Node.js', 'React', 'Xamarin']
# ['Node.js', 'React']
# ['React', 'Spring']
# ['Node.js', 'React']
# ['Node.js', 'React', 'Cordova']
# ['.NET Core']
# ['.NET Core', 'Node.js']
# ['.NET Core', 'Django', 'Node.js', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['Angular', 'Django', 'Cordova']
# ['Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core', 'Spring', 'TensorFlow']
# ['.NET Core', 'Node.js', 'Xamarin']
# ['Angular', 'Node.js']
# ['.NET Core', 'Xamarin']
# ['Hadoop', 'Spark', 'Spring']
# ['Node.js', 'Spring']
# ['Hadoop', 'Node.js', 'React', 'TensorFlow']
# ['.NET Core', 'Node.js', 'React']
# ['.NET Core']
# ['Django']
# ['.NET Core', 'Django', 'Spark']
# ['TensorFlow']
# ['.NET Core']
# ['Node.js']
# ['Angular', '.NET Core', 'Hadoop', 'Spark', 'Xamarin', 'Spring']
# ['Angular', 'Node.js']
# ['.NET Core']
# ['.NET Core']
# ['.NET Core']
# ['React']
# ['Node.js', 'Spring']
# ['Angular', '.NET Core', 'Node.js', 'Xamarin']
# ['Angular', 'Node.js', 'React', 'Cordova']
# ['Angular', 'Node.js', 'React']
# ['.NET Core']
# ['TensorFlow']
# ['Node.js']
# ['TensorFlow']
# ['Angular']
# ['.NET Core', 'Node.js', 'React']
# ['Node.js', 'React', 'Spring']
# ['Angular', '.NET Core']
# ['Angular', 'Django', 'Node.js', 'TensorFlow']
# ['.NET Core', 'Spring']
# ['Node.js']
# ['.NET Core']
# ['Django', 'React', 'TensorFlow']
# ['.NET Core', 'Spring']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', 'Django', 'Node.js']
# ['Spring']
# ['Angular', '.NET Core']
# ['Angular', '.NET Core', 'Node.js']
# ['Node.js']
# ['Django']
# ['Angular', 'Hadoop', 'Node.js']
# ['Angular', 'Node.js', 'React']
# ['.NET Core', 'Node.js']
# ['Django']
# ['.NET Core', 'Node.js']
# ['Angular', 'Spring']
# ['Angular', 'Django']
# ['Node.js']
# ['Angular', '.NET Core', 'Django', 'Hadoop', 'Node.js', 'React', 'Spark', 'Cordova', 'TensorFlow']
# ['Angular', '.NET Core', 'Django', 'TensorFlow']
# ['Node.js', 'React']
# ['.NET Core']
# ['Angular', 'Node.js', 'Spring']
# ['Node.js', 'React']
# ['Django', 'TensorFlow']
# ['Node.js', 'React', 'TensorFlow', 'Torch/PyTorch']
# ['Angular', 'Node.js', 'Spring', 'TensorFlow']
# ['Angular']
# ['.NET Core']
# ['.NET Core']
# ['Angular', 'Node.js', 'React', 'Spring']
# ['.NET Core']
# ['Angular', 'Node.js']
# ['.NET Core']
# ['Node.js', 'Spark']
# ['Node.js']
# ['Angular', '.NET Core', 'Node.js']
# ['Hadoop', 'Spark']
# ['Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js', 'Cordova', 'TensorFlow']
# ['Angular', 'Node.js', 'React']
# ['.NET Core']
# ['Angular', 'Node.js', 'Cordova']
# ['Node.js']
# ['Node.js']
# ['Angular', 'Cordova', 'TensorFlow']
# ['.NET Core', 'Node.js']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', 'Node.js', 'Spring']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Cordova', 'Spring']
# ['.NET Core']
# ['Node.js']
# ['Spring']
# ['Django']
# ['Angular']
# ['TensorFlow']
# ['Node.js', 'React']
# ['Angular', 'Node.js', 'React']
# ['Angular']
# ['Angular', 'Node.js']
# ['.NET Core', 'Xamarin']
# ['Node.js', 'Cordova']
# ['Django']
# ['Node.js', 'TensorFlow']
# ['Angular', 'Node.js', 'Cordova']
# ['.NET Core']
# ['Angular', '.NET Core', 'Node.js']
# ['Django', 'Node.js']
# ['Angular', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core', 'Node.js']
# ['Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js', 'Cordova']
# ['Node.js']
# ['Node.js', 'React', 'Spring']
# ['.NET Core']
# ['Angular', 'Django', 'Node.js', 'Spark']
# ['Node.js', 'React']
# ['Angular', '.NET Core']
# ['.NET Core', 'Node.js']
# ['Django', 'React', 'TensorFlow']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['.NET Core']
# ['.NET Core']
# ['.NET Core']
# ['Angular']
# ['Hadoop', 'Spark']
# ['Django']
# ['Angular', 'Node.js']
# ['Node.js']
# ['Angular', 'Node.js', 'React']
# ['Angular', 'Node.js']
# ['TensorFlow']
# ['Angular', '.NET Core']
# ['Node.js']
# ['Node.js', 'React']
# ['Spring']
# ['.NET Core', 'Node.js']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', 'Node.js', 'Spark', 'Spring']
# ['Angular', '.NET Core', 'Hadoop', 'Node.js', 'Spark', 'Xamarin']
# ['Angular', 'Node.js', 'Cordova', 'TensorFlow']
# ['.NET Core', 'Node.js']
# ['Angular', 'Node.js', 'Cordova']
# ['.NET Core']
# ['Node.js']
# ['Node.js', 'React']
# ['Node.js']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', 'Node.js', 'Cordova']
# ['Angular', 'Node.js']
# ['Angular', 'Node.js']
# ['Angular', 'Node.js', 'React']
# ['Angular', 'Node.js', 'Cordova']
# ['Node.js', 'React']
# ['Django']
# ['Django', 'TensorFlow']
# ['.NET Core', 'Hadoop', 'Spring']
# ['Node.js', 'React']
# ['.NET Core', 'Xamarin']
# ['Angular', 'Spark', 'Spring', 'TensorFlow']
# ['.NET Core']
# ['Angular', 'Node.js']
# ['.NET Core', 'Xamarin']
# ['Hadoop', 'React', 'Spark', 'Spring', 'TensorFlow', 'Torch/PyTorch']
# ['.NET Core']
# ['Django']
# ['.NET Core', 'Hadoop']
# ['Django', 'Node.js']
# ['Spring']
# ['Django']
# ['Angular', 'Node.js', 'Cordova', 'Spring']
# ['Angular']
# ['.NET Core']
# ['Django', 'Node.js']
# ['Angular', '.NET Core']
# ['Angular', '.NET Core', 'Xamarin']
# ['Angular', 'Node.js', 'Cordova']
# ['Angular', '.NET Core', 'React', 'Spring']
# ['Angular', 'Node.js', 'React', 'Spark', 'Cordova']
# ['React', 'Cordova']
# ['Hadoop', 'Spark', 'TensorFlow', 'Torch/PyTorch']
# ['Spring']
# ['.NET Core', 'Spring']
# ['Django']
# ['.NET Core', 'Django', 'Node.js', 'React', 'Cordova']
# ['Django']
# ['Angular', 'Node.js', 'React']
# ['.NET Core', 'Node.js']
# ['Django']
# ['Node.js']
# ['Node.js']
# ['.NET Core', 'Node.js', 'Xamarin']
# ['Node.js']
# ['Django']
# ['Node.js', 'React', 'Spring']
# ['Xamarin']
# ['Angular', '.NET Core']
# ['Angular', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js']
# ['Spark', 'Spring']
# ['.NET Core', 'Spring']
# ['.NET Core', 'React']
# ['Angular', '.NET Core', 'React']
# ['Angular', 'Django']
# ['Angular', 'Node.js', 'Cordova']
# ['Angular', 'Node.js', 'React', 'Spring']
# ['Node.js', 'React']
# ['Django']
# ['Angular', 'Django', 'Node.js', 'React', 'Spark']
# ['Angular']
# ['Angular']
# ['Angular', '.NET Core', 'Node.js']
# ['Node.js']
# ['React']
# ['Angular']
# ['Django', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core', 'Xamarin']
# ['.NET Core', 'Cordova']
# ['Angular', 'Django', 'Node.js']
# ['Angular', 'Node.js', 'Cordova']
# ['.NET Core']
# ['Angular', '.NET Core']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['.NET Core', 'Django', 'Node.js', 'React', 'Cordova']
# ['Node.js']
# ['Angular']
# ['Angular', 'Node.js']
# ['Node.js', 'React', 'Spring']
# ['Hadoop', 'Spark', 'TensorFlow']
# ['Angular']
# ['Node.js', 'React', 'Cordova']
# ['React', 'Xamarin']
# ['Node.js']
# ['Angular', '.NET Core', 'Node.js', 'Cordova', 'Xamarin']
# ['Node.js']
# ['Angular', '.NET Core', 'Node.js', 'Cordova', 'Spring']
# ['Angular', 'Node.js']
# ['Angular', '.NET Core', 'Node.js']
# ['Node.js']
# ['Node.js']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Cordova']
# ['Xamarin', 'Spring']
# ['Angular', '.NET Core', 'Xamarin']
# ['Angular']
# ['Angular', '.NET Core']
# ['Node.js', 'Spark']
# ['.NET Core', 'React', 'Xamarin']
# ['Node.js']
# ['Angular', '.NET Core', 'Node.js']
# ['Django', 'React']
# ['Angular', 'Django', 'Node.js', 'Spring']
# ['Angular']
# ['Angular', 'Node.js', 'Spring']
# ['.NET Core']
# ['.NET Core']
# ['.NET Core']
# ['Node.js', 'Cordova']
# ['.NET Core']
# ['Node.js', 'React']
# ['Angular', 'Cordova', 'Spring']
# ['Angular', '.NET Core', 'Node.js']
# ['Django', 'Node.js', 'React']
# ['Angular']
# ['.NET Core', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', 'Node.js', 'React']
# ['Node.js']
# ['Node.js', 'React', 'Spring']
# ['Angular', 'React']
# ['Node.js']
# ['Angular', 'Node.js', 'React']
# ['Django']
# ['Angular', '.NET Core', 'Django', 'Spring']
# ['.NET Core', 'Xamarin']
# ['.NET Core', 'Node.js']
# ['Angular', 'Django', 'Node.js']
# ['Django']
# ['Xamarin']
# ['.NET Core', 'Xamarin']
# ['Node.js']
# ['Django', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['Django', 'Node.js']
# ['Node.js']
# ['Django', 'Node.js', 'Cordova']
# ['React']
# ['Hadoop', 'Spark', 'TensorFlow']
# ['Django']
# ['Node.js', 'Cordova', 'Xamarin']
# ['Node.js', 'Spring']
# ['Node.js']
# ['Angular', 'React', 'Cordova']
# ['.NET Core', 'Node.js', 'React']
# ['Angular', 'React']
# ['Angular', 'Hadoop', 'Node.js']
# ['Angular', '.NET Core', 'Django', 'Node.js', 'React', 'Cordova', 'TensorFlow']
# ['Django', 'Node.js', 'React', 'Spring']
# ['Angular', '.NET Core', 'Django', 'Node.js', 'React', 'Xamarin', 'TensorFlow', 'Torch/PyTorch']
# ['.NET Core']
# ['Node.js']
# ['.NET Core']
# ['.NET Core', 'Node.js', 'React', 'TensorFlow', 'Torch/PyTorch']
# ['.NET Core']
# ['Angular', 'Node.js', 'TensorFlow']
# ['Angular', 'Node.js', 'React', 'Spring']
# ['Django']
# ['Angular', 'Node.js']
# ['.NET Core', 'Spring']
# ['Django']
# ['TensorFlow']
# ['Django', 'Node.js']
# ['Node.js']
# ['.NET Core']
# ['React']
# ['Angular', '.NET Core', 'Node.js', 'Xamarin']
# ['Node.js', 'Spring']
# ['Node.js', 'Cordova', 'Xamarin']
# ['Angular', 'Node.js', 'Spring']
# ['Node.js']
# ['Angular', 'Node.js', 'Cordova', 'Spring']
# ['Node.js']
# ['.NET Core', 'Cordova', 'Xamarin']
# ['Django', 'Node.js', 'Cordova']
# ['Hadoop']
# ['Spring']
# ['Angular', 'Django']
# ['React']
# ['Angular', 'Node.js', 'React', 'Spring']
# ['Node.js']
# ['.NET Core', 'Xamarin']
# ['Angular', 'Hadoop', 'Node.js', 'React', 'Spark']
# ['Node.js']
# ['.NET Core', 'Node.js']
# ['Node.js', 'React', 'TensorFlow']
# ['Angular', 'Node.js']
# ['Hadoop']
# ['Angular']
# ['Angular']
# ['Django', 'Spring', 'TensorFlow']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular']
# ['.NET Core', 'Django', 'Node.js', 'React', 'TensorFlow']
# ['Node.js', 'React']
# ['.NET Core', 'Node.js']
# ['Angular', '.NET Core', 'Hadoop', 'Node.js', 'Spark', 'TensorFlow']
# ['Cordova']
# ['.NET Core', 'Node.js', 'Cordova']
# ['Node.js']
# ['Angular']
# ['Spark', 'Spring']
# ['Angular', 'Node.js']
# ['Angular']
# ['Angular', 'Node.js']
# ['.NET Core', 'Node.js', 'React', 'Xamarin']
# ['Angular']
# ['Node.js', 'React']
# ['.NET Core']
# ['Node.js']
# ['Angular', '.NET Core', 'Django', 'Node.js']
# ['Angular', 'Hadoop', 'Node.js']
# ['.NET Core', 'React']
# ['Node.js']
# ['Angular', 'Node.js']
# ['Node.js', 'React', 'TensorFlow']
# ['Node.js']
# ['.NET Core', 'Node.js']
# ['.NET Core', 'Django', 'Node.js']
# ['Node.js']
# ['Angular', '.NET Core', 'Node.js', 'React', 'TensorFlow']
# ['React', 'Cordova']
# ['Node.js', 'React']
# ['.NET Core']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Spring']
# ['Node.js', 'React', 'TensorFlow']
# ['Angular', '.NET Core', 'Node.js', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js']
# ['React', 'Cordova', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Xamarin']
# ['.NET Core']
# ['Angular', 'Node.js', 'React']
# ['.NET Core', 'Spring']
# ['TensorFlow']
# ['.NET Core', 'Node.js']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Cordova', 'Xamarin']
# ['.NET Core', 'Hadoop', 'Node.js']
# ['Node.js']
# ['Hadoop', 'React', 'Spark', 'Cordova', 'Spring', 'TensorFlow', 'Torch/PyTorch']
# ['TensorFlow']
# ['Django']
# ['Spring']
# ['.NET Core', 'Node.js']
# ['Angular', 'Django', 'Node.js', 'React']
# ['Angular', 'Node.js', 'Xamarin']
# ['Angular', '.NET Core', 'Cordova']
# ['TensorFlow']
# ['Django', 'TensorFlow']
# ['Django', 'Hadoop', 'Spark']
# ['.NET Core', 'React', 'Cordova']
# ['Node.js']
# ['Angular', 'Node.js']
# ['.NET Core']
# ['Angular', '.NET Core', 'Node.js']
# ['Hadoop', 'Spark']
# ['.NET Core', 'React', 'Xamarin']
# ['Angular', 'Django', 'Node.js', 'React']
# ['.NET Core']
# ['Cordova', 'TensorFlow']
# ['Hadoop', 'Spark', 'TensorFlow']
# ['Angular']
# ['Django', 'Node.js']
# ['Node.js', 'Spring']
# ['Xamarin']
# ['.NET Core']
# ['Angular', 'Node.js']
# ['Angular', '.NET Core', 'Cordova']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Spring']
# ['Hadoop', 'Spark']
# ['Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js', 'Xamarin']
# ['Django', 'Node.js', 'React']
# ['Hadoop', 'Node.js']
# ['Angular', 'Django', 'Hadoop', 'Node.js', 'React', 'Spark', 'Cordova', 'Xamarin']
# ['.NET Core', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['Angular', '.NET Core']
# ['Angular', 'Node.js']
# ['Angular', 'Node.js', 'Spark', 'Spring']
# ['Angular']
# ['.NET Core', 'Node.js', 'React']
# ['Angular']
# ['Django']
# ['Angular']
# ['.NET Core', 'Node.js']
# ['Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js']
# ['Django', 'Node.js', 'React', 'TensorFlow']
# ['Angular', 'React']
# ['Angular', '.NET Core', 'Xamarin']
# ['Angular', 'Node.js', 'React']
# ['Angular', 'Cordova']
# ['Angular', 'Node.js', 'React', 'Cordova']
# ['.NET Core']
# ['Node.js']
# ['.NET Core']
# ['Angular', '.NET Core', 'Cordova', 'Xamarin']
# ['Django', 'Hadoop', 'Node.js', 'Spark', 'Spring']
# ['Angular', 'Xamarin']
# ['Angular', 'Django', 'Spring', 'TensorFlow']
# ['Node.js']
# ['Django', 'Node.js']
# ['Cordova']
# ['.NET Core', 'Node.js']
# ['Angular', '.NET Core', 'Cordova', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', 'Django', 'React']
# ['Angular', '.NET Core', 'Node.js', 'Cordova']
# ['.NET Core', 'React']
# ['Node.js', 'React']
# ['Angular', 'Node.js', 'React']
# ['.NET Core', 'Torch/PyTorch']
# ['Django', 'Node.js', 'React']
# ['.NET Core', 'Node.js']
# ['Node.js']
# ['Django', 'Node.js', 'Xamarin', 'Spring', 'TensorFlow']
# ['Django']
# ['TensorFlow']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core', 'Node.js', 'React']
# ['Angular']
# ['Django', 'TensorFlow']
# ['Angular', '.NET Core', 'Node.js', 'Cordova']
# ['Node.js', 'React', 'Xamarin', 'TensorFlow', 'Torch/PyTorch']
# ['.NET Core', 'Node.js', 'React', 'Cordova', 'Xamarin', 'Spring']
# ['.NET Core']
# ['Angular', 'React']
# ['Spring']
# ['Angular', '.NET Core', 'Django', 'Node.js', 'React', 'Cordova']
# ['Node.js', 'React']
# ['Django']
# ['Angular', '.NET Core']
# ['Angular', 'Django', 'Node.js', 'React', 'Cordova']
# ['React']
# ['Django', 'Hadoop', 'Node.js', 'React']
# ['Angular', 'Django']
# ['Django', 'Node.js', 'Spring']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', 'Hadoop', 'Node.js']
# ['Angular', 'Node.js', 'Spring']
# ['Django', 'Spring']
# ['Angular', '.NET Core']
# ['Node.js', 'React']
# ['Hadoop', 'Spark', 'Spring']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Cordova', 'Xamarin']
# ['Node.js', 'Spark', 'Xamarin']
# ['Node.js', 'React']
# ['.NET Core', 'Node.js', 'React', 'Spring']
# ['Angular', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Cordova', 'Xamarin']
# ['Angular', 'Node.js', 'React', 'Cordova']
# ['React']
# ['Angular', '.NET Core', 'Django', 'Node.js']
# ['Angular', 'Django']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core', 'Node.js', 'React']
# ['Angular', 'Node.js', 'React']
# ['Angular', 'Node.js', 'React']
# ['.NET Core', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js', 'Cordova', 'Xamarin']
# ['Django', 'Node.js', 'React', 'TensorFlow']
# ['Node.js']
# ['Django', 'Hadoop', 'Node.js', 'TensorFlow', 'Torch/PyTorch']
# ['Angular', '.NET Core']
# ['Node.js']
# ['Node.js']
# ['Angular', 'Node.js', 'Cordova']
# ['TensorFlow']
# ['Angular', 'Node.js', 'React', 'Cordova']
# ['Django', 'TensorFlow']
# ['Angular', 'Node.js', 'Spring']
# ['.NET Core', 'Xamarin']
# ['Angular', '.NET Core', 'Django', 'Node.js']
# ['Xamarin']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Cordova', 'Xamarin']
# ['.NET Core', 'Django']
# ['.NET Core', 'Node.js']
# ['Angular', 'Node.js']
# ['Cordova']
# ['.NET Core']
# ['.NET Core']
# ['Angular', 'Spring']
# ['.NET Core']
# ['Django']
# ['Node.js']
# ['Angular', 'Django']
# ['Node.js', 'React']
# ['Xamarin']
# ['Angular', 'Django', 'Node.js']
# ['Angular', 'Node.js', 'React']
# ['.NET Core', 'Django', 'Node.js', 'Spring']
# ['.NET Core']
# ['.NET Core']
# ['Node.js']
# ['Angular', 'Spring']
# ['Node.js', 'React', 'TensorFlow']
# ['Node.js', 'React']
# ['Django', 'Node.js', 'Spark']
# ['Django']
# ['Angular', 'Django', 'TensorFlow']
# ['Angular']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', 'Django', 'Node.js', 'React', 'Cordova']
# ['.NET Core', 'Django', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js']
# ['Spring']
# ['Django', 'React']
# ['Node.js', 'Cordova', 'Spring']
# ['Django', 'TensorFlow', 'Torch/PyTorch']
# ['Angular', 'Django']
# ['Node.js', 'React']
# ['Angular', 'Node.js', 'Cordova']
# ['Angular', 'Cordova']
# ['Angular', '.NET Core']
# ['Node.js']
# ['.NET Core', 'Xamarin']
# ['Django']
# ['.NET Core', 'Django', 'Hadoop']
# ['Angular', 'Node.js']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Xamarin']
# ['Angular', 'Cordova']
# ['Django', 'Node.js']
# ['Django', 'Spring']
# ['React']
# ['Node.js', 'React']
# ['Django', 'Node.js', 'React']
# ['Angular', 'Node.js']
# ['React']
# ['Node.js']
# ['Angular', 'Node.js', 'React', 'Spring', 'TensorFlow']
# ['Hadoop', 'React', 'Spark']
# ['.NET Core']
# ['Node.js']
# ['Angular', '.NET Core', 'React']
# ['Angular', 'Node.js', 'Cordova']
# ['Angular', 'Spring']
# ['Django', 'Hadoop']
# ['Django']
# ['Angular']
# ['.NET Core', 'Xamarin']
# ['Django', 'Spark']
# ['Django', 'Torch/PyTorch']
# ['Node.js', 'React']
# ['Angular', 'Node.js', 'React']
# ['Node.js']
# ['Angular', 'Cordova', 'Spring']
# ['Angular', 'Node.js']
# ['Angular', 'Node.js', 'Spring', 'TensorFlow', 'Torch/PyTorch']
# ['Angular', 'Node.js', 'React']
# ['Angular', 'Spring']
# ['Spring']
# ['.NET Core', 'Django', 'Node.js', 'Spring']
# ['Angular', 'Django', 'Node.js', 'Spring', 'TensorFlow']
# ['Angular', 'Django']
# ['Angular', '.NET Core', 'Hadoop', 'Node.js', 'React', 'Spark', 'Cordova', 'Xamarin', 'TensorFlow']
# ['Angular', 'Django', 'Node.js', 'React', 'Spring']
# ['.NET Core', 'Node.js']
# ['Node.js', 'React']
# ['Node.js']
# ['Angular', 'Node.js']
# ['React']
# ['Angular', '.NET Core']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core', 'Node.js', 'React']
# ['Hadoop', 'Node.js']
# ['Spring']
# ['Angular', '.NET Core']
# ['Angular']
# ['Spring']
# ['Hadoop']
# ['Angular', 'Node.js']
# ['Angular', '.NET Core', 'Node.js', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core', 'Django', 'React']
# ['.NET Core', 'Node.js', 'Xamarin']
# ['Hadoop', 'Spark']
# ['Node.js']
# ['Angular', '.NET Core', 'Spring']
# ['Angular', 'Node.js']
# ['Spring']
# ['Angular', 'Node.js', 'Spark', 'TensorFlow']
# ['React', 'Cordova', 'Xamarin']
# ['Django']
# ['Node.js', 'React', 'TensorFlow']
# ['Node.js']
# ['Spring']
# ['Angular', 'Node.js', 'React', 'TensorFlow']
# ['Angular']
# ['Angular', 'Django', 'TensorFlow']
# ['Angular', 'Node.js', 'Spark']
# ['Node.js']
# ['Node.js', 'React']
# ['Django']
# ['Angular', '.NET Core']
# ['Node.js']
# ['Node.js', 'React']
# ['Angular', '.NET Core']
# ['.NET Core']
# ['Node.js']
# ['Spark']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Xamarin']
# ['Node.js']
# ['Angular', 'Node.js']
# ['.NET Core']
# ['Angular', 'Hadoop', 'Node.js']
# ['Angular', '.NET Core']
# ['Django', 'Node.js', 'React']
# ['Node.js', 'Spring']
# ['Hadoop']
# ['Cordova']
# ['Django', 'Node.js']
# ['Angular', 'Node.js', 'React']
# ['Angular', 'Node.js', 'Spark', 'Spring']
# ['.NET Core', 'Node.js']
# ['Angular', '.NET Core', 'Node.js']
# ['Xamarin']
# ['Angular', 'Spring']
# ['Angular', 'Node.js', 'Spark', 'Spring']
# ['Node.js', 'React', 'TensorFlow', 'Torch/PyTorch']
# ['Hadoop', 'Spark', 'Spring']
# ['Node.js', 'React']
# ['Angular', 'Node.js', 'React', 'Spring']
# ['Spring']
# ['Angular', 'Node.js', 'React']
# ['Django', 'Node.js']
# ['Angular', '.NET Core', 'Node.js', 'Spring']
# ['Node.js', 'React']
# ['.NET Core', 'Node.js']
# ['TensorFlow']
# ['Angular', 'Node.js']
# ['React']
# ['Node.js']
# ['Angular', 'Hadoop', 'Node.js']
# ['Angular', 'Django', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core', 'Xamarin']
# ['Angular', 'Hadoop', 'Node.js', 'React']
# ['.NET Core']
# ['Angular', 'Node.js', 'Spring']
# ['Hadoop', 'Spark']
# ['.NET Core']
# ['Angular']
# ['Django', 'Node.js', 'TensorFlow']
# ['Django']
# ['Angular']
# ['.NET Core', 'Node.js']
# ['Angular', 'Node.js', 'Cordova']
# ['Angular', '.NET Core', 'Django', 'Node.js', 'React', 'Cordova', 'Spring']
# ['Angular', 'Node.js', 'React']
# ['Node.js']
# ['.NET Core', 'Xamarin']
# ['Angular', 'Hadoop', 'Node.js', 'Spring']
# ['Angular', 'Node.js']
# ['Angular']
# ['.NET Core']
# ['Angular', 'Node.js', 'Spring']
# ['Django', 'React']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', 'Spring']
# ['Angular', '.NET Core']
# ['.NET Core', 'Node.js']
# ['Node.js']
# ['Angular', 'Node.js']
# ['Node.js', 'React']
# ['Node.js']
# ['Node.js']
# ['Django', 'Cordova']
# ['Angular', 'Django', 'Node.js']
# ['Node.js', 'React', 'TensorFlow']
# ['React', 'Spring']
# ['.NET Core', 'Node.js']
# ['Node.js']
# ['Angular', '.NET Core']
# ['.NET Core', 'Node.js']
# ['Node.js']
# ['Spark', 'TensorFlow']
# ['Angular', '.NET Core', 'Cordova']
# ['Django', 'React']
# ['.NET Core', 'Node.js', 'React']
# ['Node.js', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', 'Node.js', 'React']
# ['Node.js']
# ['Angular']
# ['Node.js', 'React']
# ['React', 'TensorFlow']
# ['.NET Core']
# ['.NET Core', 'Spring']
# ['.NET Core']
# ['Node.js', 'React']
# ['Angular', 'Node.js', 'Cordova']
# ['Angular', 'Cordova', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js', 'Cordova']
# ['Spring']
# ['Angular', 'Node.js', 'React']
# ['TensorFlow']
# ['Angular', 'Node.js', 'React']
# ['Node.js', 'React']
# ['Node.js']
# ['Angular', 'Spring']
# ['Hadoop']
# ['.NET Core', 'Node.js', 'React']
# ['Node.js', 'React']
# ['Angular', 'Node.js', 'Spring']
# ['Angular']
# ['Angular', 'Spring']
# ['Hadoop', 'Node.js', 'Spring']
# ['Django']
# ['Angular', 'Node.js']
# ['Django', 'Spring']
# ['Angular', 'Node.js', 'Spring']
# ['Angular', 'Node.js', 'React']
# ['Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', '.NET Core', 'Node.js', 'Xamarin']
# ['React']
# ['Angular', 'Django', 'Node.js', 'TensorFlow']
# ['Node.js', 'React']
# ['Angular', '.NET Core']
# ['Angular', 'Node.js', 'React', 'Cordova', 'TensorFlow']
# ['Django']
# ['Angular', 'Django', 'Node.js', 'React']
# ['.NET Core']
# ['Angular', 'Django']
# ['Node.js']
# ['Angular', 'Node.js', 'React', 'TensorFlow', 'Torch/PyTorch']
# ['Django', 'Node.js', 'React']
# ['.NET Core', 'Django']
# ['.NET Core']
# ['Angular', '.NET Core', 'Hadoop', 'Spark', 'Spring', 'TensorFlow']
# ['TensorFlow', 'Torch/PyTorch']
# ['Angular', '.NET Core', 'Xamarin']
# ['Angular', '.NET Core']
# ['.NET Core', 'Node.js']
# ['.NET Core']
# ['Angular', 'Node.js', 'Cordova', 'Xamarin', 'Spring']
# ['Angular', 'Node.js', 'React']
# ['.NET Core']
# ['Node.js']
# ['Django', 'React']
# ['Angular', 'TensorFlow']
# ['.NET Core', 'Xamarin']
# ['React']
# ['Django']
# ['.NET Core']
# ['Angular', 'Node.js', 'Spring']
# ['TensorFlow']
# ['.NET Core']
# ['Angular', 'Node.js']
# ['Node.js']
# ['Node.js']
# ['Angular', '.NET Core', 'Xamarin']
# ['Angular', '.NET Core', 'Django', 'Hadoop', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js', 'Cordova']
# ['Node.js', 'Spring']
# ['Hadoop', 'Node.js']
# ['Spring', 'TensorFlow']
# ['.NET Core', 'React']
# ['.NET Core']
# ['Angular', 'Node.js']
# ['Node.js', 'React']
# ['Xamarin']
# ['Angular', 'Node.js', 'React', 'Spring']
# ['Django', 'Node.js']
# ['Angular', 'Django']
# ['.NET Core']
# ['Spring']
# ['Angular', 'Node.js', 'React', 'TensorFlow', 'Torch/PyTorch']
# ['.NET Core', 'Node.js']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Cordova', 'Xamarin']
# ['Angular', 'Django', 'Cordova', 'Spring']
# ['Django']
# ['Angular', 'Node.js', 'Spring']
# ['Node.js']
# ['Angular', 'Django', 'React', 'Spring']
# ['Angular', 'Node.js', 'React', 'Spring', 'TensorFlow']
# ['Angular', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js', 'Cordova', 'Xamarin']
# ['.NET Core', 'Node.js']
# ['Angular', 'Hadoop', 'Node.js', 'Spark']
# ['.NET Core']
# ['Node.js']
# ['.NET Core']
# ['Cordova', 'TensorFlow']
# ['Node.js', 'TensorFlow']
# ['.NET Core', 'Xamarin']
# ['Node.js']
# ['Hadoop', 'Node.js', 'Spark']
# ['Angular', 'Node.js', 'Cordova']
# ['Angular', '.NET Core']
# ['.NET Core']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core', 'Xamarin']
# ['.NET Core']
# ['Xamarin']
# ['Cordova', 'Spring']
# ['.NET Core']
# ['Angular', 'Django']
# ['Django', 'Node.js', 'Spring', 'TensorFlow']
# ['Node.js', 'React']
# ['Spring']
# ['Angular', 'Hadoop', 'Node.js']
# ['.NET Core']
# ['Spring']
# ['Hadoop', 'Node.js', 'React']
# ['Angular', 'React']
# ['Node.js', 'React', 'Cordova']
# ['React', 'Xamarin']
# ['Angular', 'Spark']
# ['Node.js']
# ['.NET Core', 'Node.js']
# ['Node.js', 'React']
# ['Django']
# ['Angular']
# ['Hadoop']
# ['Angular', 'Node.js']
# ['Angular', 'Node.js', 'React', 'Cordova', 'Spring', 'TensorFlow']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', '.NET Core']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core']
# ['Spring']
# ['Angular', 'Node.js', 'React', 'TensorFlow']
# ['Angular', 'Node.js']
# ['Angular', 'Hadoop', 'Spark', 'Spring']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['.NET Core', 'Node.js']
# ['Django', 'Spark']
# ['.NET Core', 'Hadoop', 'Node.js', 'Spring']
# ['Angular', 'Node.js']
# ['Angular', '.NET Core']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Xamarin']
# ['Node.js']
# ['Angular', 'Node.js', 'Spring']
# ['Angular']
# ['Node.js', 'React']
# ['Node.js', 'React']
# ['.NET Core']
# ['Node.js']
# ['Django']
# ['Angular', 'Node.js', 'React']
# ['Angular', 'Node.js', 'Spring']
# ['Angular', 'Xamarin']
# ['Angular', 'Node.js', 'Cordova']
# ['Node.js', 'React']
# ['React']
# ['Node.js']
# ['Hadoop', 'Spark', 'TensorFlow']
# ['.NET Core', 'Node.js', 'Cordova', 'Xamarin']
# ['Django']
# ['Angular', 'Node.js', 'React']
# ['Django']
# ['Django']
# ['React']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Cordova']
# ['.NET Core', 'Xamarin']
# ['.NET Core']
# ['.NET Core', 'Node.js', 'React']
# ['Angular', 'Node.js', 'React']
# ['Node.js', 'React']
# ['Angular', 'Node.js']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['Node.js']
# ['Angular', '.NET Core']
# ['Angular', 'Node.js', 'React', 'Cordova']
# ['Node.js', 'Spark']
# ['Angular', 'Hadoop', 'Node.js', 'React', 'Spring']
# ['Angular', '.NET Core', 'Node.js', 'Xamarin']
# ['.NET Core', 'Django']
# ['.NET Core']
# ['Angular', 'Node.js', 'Cordova']
# ['Angular', 'Node.js']
# ['Django']
# ['Angular', '.NET Core', 'Spring']
# ['Django']
# ['React']
# ['Cordova']
# ['Angular', 'Node.js', 'React', 'Spring']
# ['Angular', 'Spring']
# ['.NET Core', 'Node.js']
# ['Angular', 'Node.js', 'React']
# ['Node.js', 'React']
# ['.NET Core']
# ['Angular']
# ['Node.js']
# ['Node.js', 'React']
# ['Angular', 'Django', 'TensorFlow']
# ['.NET Core']
# ['Node.js']
# ['Angular', 'Node.js', 'Cordova']
# ['Node.js']
# ['Node.js']
# ['Node.js', 'React']
# ['Angular', 'Node.js', 'Cordova']
# ['Django', 'Node.js']
# ['Django', 'Node.js']
# ['Spring']
# ['.NET Core', 'Node.js', 'Cordova', 'Xamarin']
# ['.NET Core']
# ['Angular', '.NET Core', 'Spring']
# ['Angular']
# ['Node.js']
# ['Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js']
# ['Django']
# ['Angular', 'Node.js', 'Spring']
# ['Angular', 'Django']
# ['Node.js', 'React']
# ['Django', 'React']
# ['Hadoop', 'Spring']
# ['Angular']
# ['Spark', 'Spring']
# ['Django']
# ['Node.js', 'React']
# ['Django', 'Node.js']
# ['.NET Core']
# ['TensorFlow']
# ['.NET Core']
# ['.NET Core']
# ['React', 'Spring']
# ['.NET Core']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['.NET Core', 'React']
# ['Angular', '.NET Core', 'Hadoop', 'Node.js']
# ['Angular', '.NET Core', 'Xamarin']
# ['Node.js']
# ['Node.js']
# ['Angular', 'Spring']
# ['Django', 'React', 'Cordova']
# ['Angular']
# ['Xamarin']
# ['React', 'Spring']
# ['.NET Core', 'Xamarin']
# ['Angular', '.NET Core', 'Xamarin']
# ['.NET Core', 'Django', 'Node.js', 'Cordova']
# ['React', 'TensorFlow']
# ['TensorFlow']
# ['Django', 'Hadoop', 'Node.js', 'React']
# ['Angular', '.NET Core']
# ['Angular', 'Django', 'Node.js', 'React', 'TensorFlow']
# ['Django', 'React']
# ['Angular', 'Spring']
# ['Hadoop']
# ['Hadoop', 'Spark', 'TensorFlow', 'Torch/PyTorch']
# ['.NET Core']
# ['Django', 'Node.js', 'TensorFlow', 'Torch/PyTorch']
# ['Spring']
# ['Angular', 'Django', 'Hadoop', 'Node.js', 'React', 'TensorFlow']
# ['Node.js', 'React', 'Xamarin']
# ['Node.js']
# ['Node.js', 'TensorFlow']
# ['Node.js', 'Spring']
# ['Node.js']
# ['Angular', 'Node.js']
# ['.NET Core', 'Node.js', 'React']
# ['TensorFlow']
# ['Cordova', 'Spring']
# ['.NET Core', 'Node.js']
# ['.NET Core']
# ['Django', 'Node.js', 'React', 'TensorFlow']
# ['React', 'Spring']
# ['Angular', 'Node.js', 'Cordova']
# ['.NET Core', 'Node.js', 'Cordova']
# ['TensorFlow']
# ['Angular', 'Node.js', 'React']
# ['TensorFlow']
# ['Angular', 'Spring']
# ['Node.js', 'React', 'Spring']
# ['Cordova', 'Xamarin']
# ['.NET Core']
# ['.NET Core']
# ['Angular']
# ['Spring']
# ['Angular', '.NET Core', 'React']
# ['Angular', 'Node.js', 'React']
# ['Spring']
# ['React']
# ['Angular', 'Node.js']
# ['Angular']
# ['Spring']
# ['TensorFlow', 'Torch/PyTorch']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Cordova', 'Xamarin']
# ['.NET Core']
# ['Angular']
# ['Angular', '.NET Core', 'Node.js', 'TensorFlow']
# ['Spark']
# ['Spring']
# ['Node.js', 'React', 'Spring']
# ['Django']
# ['.NET Core', 'Node.js']
# ['Angular', 'Node.js']
# ['Angular', 'Node.js', 'Cordova']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', 'Node.js', 'React']
# ['Angular', 'Django', 'Node.js', 'TensorFlow']
# ['Angular', 'Django', 'Node.js']
# ['.NET Core', 'Hadoop', 'Node.js', 'Spring']
# ['Django', 'Node.js', 'React', 'TensorFlow']
# ['Spring']
# ['Hadoop', 'Node.js']
# ['Angular']
# ['Angular']
# ['Xamarin']
# ['.NET Core']
# ['.NET Core', 'Node.js', 'React']
# ['React']
# ['Angular', 'Django', 'Node.js']
# ['Angular', 'Node.js', 'Spring']
# ['Node.js']
# ['Angular', 'Django', 'Node.js', 'Spring', 'TensorFlow']
# ['Django', 'TensorFlow']
# ['.NET Core', 'Node.js', 'Xamarin']
# ['Angular', 'Node.js']
# ['Angular', 'Node.js']
# ['.NET Core']
# ['Node.js', 'React']
# ['Spring']
# ['Angular', 'Node.js', 'React']
# ['Node.js', 'TensorFlow']
# ['.NET Core', 'Node.js']
# ['Angular', 'Node.js', 'Cordova']
# ['.NET Core', 'Hadoop']
# ['Angular', '.NET Core', 'Node.js']
# ['Node.js', 'Xamarin']
# ['Angular']
# ['Angular']
# ['Node.js', 'React', 'Xamarin']
# ['TensorFlow']
# ['Spring']
# ['Django', 'Node.js']
# ['Node.js', 'Spring']
# ['Angular', 'Node.js']
# ['.NET Core', 'Node.js', 'TensorFlow']
# ['Node.js', 'React', 'Spring']
# ['.NET Core']
# ['Django']
# ['TensorFlow']
# ['Angular', '.NET Core', 'Django', 'Node.js']
# ['Django', 'Xamarin']
# ['.NET Core']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['Node.js', 'React']
# ['Angular']
# ['Angular', 'React', 'Spring']
# ['.NET Core']
# ['Angular', 'Django', 'Hadoop', 'Node.js', 'React', 'Spring']
# ['Angular', 'Node.js', 'React', 'Spring']
# ['Hadoop', 'Node.js', 'React', 'Spark', 'TensorFlow']
# ['Angular', 'Cordova']
# ['Django', 'Node.js', 'React', 'TensorFlow']
# ['Angular']
# ['Spring']
# ['.NET Core', 'Node.js', 'Spring']
# ['Django', 'React']
# ['React']
# ['Angular', 'Cordova']
# ['Angular', '.NET Core', 'Cordova']
# ['.NET Core', 'Xamarin']
# ['Angular', '.NET Core']
# ['Spring']
# ['Hadoop', 'Node.js', 'Spark', 'Spring']
# ['.NET Core', 'Node.js', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js']
# ['Spark', 'TensorFlow']
# ['.NET Core', 'Node.js', 'Xamarin', 'Spring']
# ['Spark']
# ['.NET Core']
# ['Angular', '.NET Core', 'Node.js', 'Spring']
# ['Node.js']
# ['React', 'Spring']
# ['Xamarin']
# ['.NET Core', 'Node.js', 'Xamarin']
# ['.NET Core']
# ['.NET Core']
# ['Angular', '.NET Core', 'Django', 'Node.js', 'React', 'TensorFlow']
# ['Angular', 'Node.js', 'Spring']
# ['Angular']
# ['Django']
# ['.NET Core', 'Django', 'Node.js']
# ['Angular', 'Node.js', 'React']
# ['React']
# ['.NET Core', 'Xamarin']
# ['Angular', 'Django', 'Node.js', 'React']
# ['Django', 'Node.js', 'React']
# ['.NET Core']
# ['.NET Core', 'Node.js', 'React']
# ['Hadoop', 'Node.js', 'Spark', 'Spring']
# ['Angular', 'Node.js']
# ['Node.js', 'React']
# ['Node.js', 'React']
# ['Node.js', 'React']
# ['Angular', 'Node.js', 'React']
# ['Angular', 'Node.js', 'React']
# ['.NET Core']
# ['Angular', 'Django', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js', 'TensorFlow']
# ['Angular', 'Node.js', 'React']
# ['Angular', '.NET Core']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core', 'Node.js']
# ['.NET Core']
# ['Node.js', 'TensorFlow']
# ['Spring']
# ['Node.js', 'React', 'TensorFlow']
# ['.NET Core']
# ['.NET Core', 'Xamarin']
# ['Angular', 'Node.js', 'React', 'Spark']
# ['Django']
# ['Django', 'Node.js', 'React']
# ['.NET Core']
# ['Angular', '.NET Core', 'Node.js', 'Spark']
# ['Angular', 'Node.js']
# ['Angular', 'Node.js']
# ['Angular', 'Node.js', 'TensorFlow']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', 'Node.js', 'React']
# ['Spring']
# ['.NET Core', 'Node.js']
# ['.NET Core']
# ['Angular', '.NET Core']
# ['Angular', 'Node.js', 'Spring']
# ['Node.js']
# ['.NET Core', 'Node.js', 'Xamarin']
# ['Cordova']
# ['Spring']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['React', 'Spring']
# ['Node.js', 'React', 'Spring']
# ['Node.js']
# ['Node.js', 'Spring']
# ['Node.js', 'Spring', 'TensorFlow', 'Torch/PyTorch']
# ['.NET Core', 'Node.js']
# ['Angular', 'Node.js', 'Cordova']
# ['Angular', 'Node.js']
# ['Django', 'Node.js', 'React', 'Cordova', 'Spring']
# ['Node.js', 'Cordova', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core']
# ['Node.js', 'React']
# ['Angular', 'Django', 'Node.js']
# ['.NET Core', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js', 'Xamarin']
# ['Angular', 'Node.js']
# ['.NET Core']
# ['.NET Core']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js', 'Xamarin']
# ['.NET Core']
# ['Angular', 'Node.js', 'React', 'Spring']
# ['Django']
# ['.NET Core', 'Node.js']
# ['Angular', '.NET Core', 'Hadoop', 'Spark', 'Spring']
# ['Angular', 'Spring']
# ['Hadoop', 'TensorFlow']
# ['.NET Core', 'React', 'Xamarin']
# ['.NET Core']
# ['Angular', 'Node.js', 'Spark', 'Cordova', 'TensorFlow']
# ['Node.js', 'React']
# ['.NET Core']
# ['Angular', 'Node.js']
# ['Angular', 'TensorFlow']
# ['Django']
# ['Cordova']
# ['Angular', 'Node.js', 'TensorFlow']
# ['.NET Core', 'Node.js']
# ['.NET Core']
# ['Angular', 'Node.js', 'React']
# ['React', 'Cordova']
# ['Spring']
# ['Angular', 'Node.js']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['Node.js', 'React']
# ['Angular', 'Node.js']
# ['Django', 'Node.js']
# ['Angular', 'Node.js', 'React', 'Xamarin']
# ['Angular', '.NET Core']
# ['Angular', '.NET Core', 'Node.js', 'TensorFlow']
# ['Django', 'Spring', 'TensorFlow', 'Torch/PyTorch']
# ['Angular', '.NET Core', 'Node.js', 'Cordova', 'Xamarin']
# ['Angular', 'Django', 'React', 'Spark', 'TensorFlow']
# ['Node.js', 'React', 'Spring']
# ['Angular', '.NET Core']
# ['.NET Core']
# ['TensorFlow']
# ['.NET Core', 'Node.js']
# ['Node.js']
# ['Node.js', 'Cordova']
# ['Angular', 'Node.js']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Spring']
# ['Xamarin']
# ['Angular', 'Node.js', 'React']
# ['Angular', 'Django', 'Node.js', 'Cordova']
# ['Xamarin']
# ['Angular', 'Django', 'React', 'Cordova']
# ['Angular', 'Node.js']
# ['Django']
# ['Node.js', 'React']
# ...
# ['Angular', 'Django']
# ['Angular', 'Node.js']
# ['.NET Core', 'Node.js']
# ['Angular', 'Node.js', 'Cordova']
# ['Node.js', 'React', 'Cordova']
# ['Angular', '.NET Core', 'Node.js']
# ['Node.js', 'Cordova']
# ['.NET Core']
# ['Angular', '.NET Core', 'Node.js']
# ['Node.js', 'TensorFlow']
# ['Node.js', 'Xamarin']
# ['.NET Core']
# ['Angular', 'Node.js', 'Spring']
# ['Angular', 'Node.js', 'React']
# ['.NET Core', 'Node.js', 'React']
# ['Angular', '.NET Core']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['Angular', '.NET Core']
# ['Angular', 'Node.js', 'Spring']
# ['Node.js']
# ['Node.js', 'React']
# ['Django', 'React']
# ['Node.js', 'Cordova']
# ['.NET Core', 'Node.js']
# ['Hadoop', 'Node.js', 'Spark', 'Spring']
# ['Node.js']
# ['.NET Core']
# ['Django', 'Spark', 'Spring']
# ['.NET Core', 'Xamarin']
# ['.NET Core']
# ['Angular', 'Node.js']
# ['.NET Core']
# ['.NET Core']
# ['Django', 'Hadoop', 'Torch/PyTorch']
# ['Django']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['.NET Core']
# ['Angular', 'Node.js']
# ['.NET Core', 'Cordova']
# ['Angular', '.NET Core', 'Node.js']
# ['Spring']
# ['Node.js']
# ['Node.js']
# ['Angular', 'Django', 'Node.js', 'React']
# ['Django', 'Node.js']
# ['React']
# ['Spring']
# ['Angular', 'Node.js']
# ['Node.js', 'React']
# ['Django']
# ['.NET Core']
# ['.NET Core', 'Xamarin']
# ['.NET Core', 'Node.js', 'Xamarin']
# ['.NET Core']
# ['React']
# ['.NET Core', 'Django', 'React']
# ['Angular', 'Node.js']
# ['Node.js']
# ['Node.js']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', 'Node.js', 'React']
# ['Node.js']
# ['Hadoop', 'Node.js', 'Spark', 'TensorFlow']
# ['.NET Core', 'Xamarin']
# ['Spring', 'Torch/PyTorch']
# ['Angular', 'Hadoop', 'Node.js', 'React', 'Spark', 'TensorFlow']
# ['Angular', '.NET Core', 'Node.js']
# ['Node.js']
# ['Django']
# ['Angular', 'Spring']
# ['Angular']
# ['Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core']
# ['Angular', 'Cordova']
# ['Cordova']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', 'Hadoop', 'Node.js', 'TensorFlow']
# ['Angular', 'Node.js']
# ['Angular', 'Node.js']
# ['.NET Core']
# ['Node.js']
# ['.NET Core', 'Xamarin']
# ['Node.js']
# ['Angular', '.NET Core', 'Node.js']
# ['Node.js', 'React']
# ['Django']
# ['Angular']
# ['Angular', 'Django', 'Node.js', 'TensorFlow']
# ['Angular', 'Django', 'Node.js']
# ['Angular', 'React']
# ['Angular', 'Node.js']
# ['Angular', 'Django']
# ['Angular', '.NET Core']
# ['Node.js', 'React', 'Cordova']
# ['Django']
# ['.NET Core']
# ['Angular', '.NET Core', 'Node.js', 'Cordova', 'TensorFlow', 'Torch/PyTorch']
# ['Angular', 'Hadoop', 'Node.js', 'Spark', 'Spring', 'TensorFlow']
# ['Angular', 'Node.js', 'React']
# ['Angular', '.NET Core']
# ['TensorFlow']
# ['TensorFlow']
# ['.NET Core', 'Xamarin', 'TensorFlow']
# ['Node.js', 'Spring']
# ['Hadoop', 'Spark']
# ['.NET Core', 'Node.js', 'React']
# ['Django', 'React']
# ['Django', 'Spark']
# ['Node.js', 'React']
# ['Angular', 'Node.js']
# ['React', 'Spring']
# ['Angular', 'Django', 'Node.js', 'TensorFlow']
# ['.NET Core', 'Xamarin']
# ['Django', 'Node.js', 'React', 'Spring', 'TensorFlow']
# ['Angular', 'Node.js', 'React']
# ['.NET Core', 'Node.js']
# ['Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js']
# ['Node.js', 'React', 'Spark', 'Spring', 'TensorFlow']
# ['Node.js', 'React']
# ['Spark']
# ['Angular', 'Node.js']
# ['.NET Core', 'Node.js']
# ['Node.js', 'React']
# ['Node.js', 'Cordova']
# ['Spring']
# ['.NET Core', 'React']
# ['React', 'Spring']
# ['Django']
# ['.NET Core']
# ['Angular', 'Node.js', 'React', 'Spring']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Cordova', 'Xamarin']
# ['Angular', 'Node.js']
# ['Node.js']
# ['Hadoop', 'Spring']
# ['Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js']
# ['React']
# ['Django', 'Node.js']
# ['.NET Core', 'Node.js', 'Cordova']
# ['Angular', 'Node.js']
# ['Angular', '.NET Core', 'Node.js', 'Xamarin']
# ['React']
# ['Angular', 'Node.js', 'Spring']
# ['Node.js', 'React']
# ['Django', 'React']
# ['Hadoop', 'Spark', 'Spring']
# ['Angular', '.NET Core', 'Cordova']
# ['.NET Core']
# ['Angular']
# ['Node.js', 'React']
# ['Angular']
# ['Angular', 'React']
# ['Node.js', 'React', 'TensorFlow']
# ['Angular', 'Node.js']
# ['Node.js']
# ['Angular', 'Django', 'Node.js']
# ['.NET Core', 'Xamarin']
# ['Angular', '.NET Core']
# ['React']
# ['Angular', 'Node.js']
# ['.NET Core']
# ['Angular', 'Node.js']
# ['.NET Core', 'Xamarin']
# ['Angular', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Django', 'Hadoop', 'Node.js', 'React', 'Cordova', 'Xamarin', 'Spring']
# ['Hadoop', 'Node.js', 'Spring']
# ['Angular', 'Hadoop', 'Node.js', 'React', 'Spring']
# ['.NET Core', 'Xamarin']
# ['Spring']
# ['Django']
# ['Angular', '.NET Core', 'Cordova']
# ['Node.js', 'React', 'Cordova']
# ['Angular', '.NET Core']
# ['Angular', 'Node.js', 'React', 'Cordova']
# ['.NET Core']
# ['Node.js']
# ['Angular', 'Django', 'Node.js']
# ['Xamarin']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['Node.js']
# ['Angular', 'Node.js', 'Spring']
# ['.NET Core', 'Node.js', 'React']
# ['Node.js', 'Cordova']
# ['React']
# ['Angular', 'Node.js']
# ['Angular', 'Node.js', 'React', 'Spark']
# ['Angular', 'Node.js']
# ['.NET Core', 'Django', 'Xamarin']
# ['Spring']
# ['Angular', 'Node.js', 'React', 'Spring']
# ['Angular']
# ['Spring']
# ['Angular', 'Django', 'Node.js', 'React', 'Cordova', 'Spring']
# ['Angular', 'Hadoop', 'Node.js', 'Spring']
# ['Angular', 'Node.js']
# ['Angular', '.NET Core', 'Cordova', 'Xamarin']
# ['Angular', 'Node.js']
# ['.NET Core']
# ['.NET Core', 'Node.js', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core']
# ['Node.js', 'React']
# ['Node.js', 'React']
# ['Hadoop']
# ['Angular', '.NET Core']
# ['Angular', 'Hadoop', 'Node.js', 'Spark', 'Spring']
# ['.NET Core']
# ['Node.js', 'React']
# ['Node.js', 'React', 'Torch/PyTorch']
# ['.NET Core', 'Node.js', 'React']
# ['Node.js']
# ['Angular', '.NET Core', 'Node.js', 'Spring']
# ['Cordova']
# ['Angular', 'Django', 'Node.js']
# ['Node.js', 'TensorFlow']
# ['.NET Core', 'Spring']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core', 'Xamarin']
# ['React']
# ['Hadoop', 'Spark', 'Spring', 'TensorFlow']
# ['Spark', 'TensorFlow', 'Torch/PyTorch']
# ['.NET Core', 'Node.js', 'React']
# ['Node.js']
# ['Angular', 'Node.js']
# ['Angular', 'Node.js', 'Spring']
# ['Spring']
# ['Angular', 'Django', 'Node.js', 'React']
# ['Node.js']
# ['Angular', '.NET Core', 'Xamarin']
# ['Hadoop', 'Node.js']
# ['Node.js', 'React']
# ['Spring']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Xamarin', 'TensorFlow']
# ['.NET Core', 'React', 'Xamarin']
# ['Angular', '.NET Core']
# ['Spring']
# ['Node.js', 'React', 'Spring']
# ['Node.js', 'React']
# ['Angular', '.NET Core', 'Xamarin']
# ['Angular', 'Node.js', 'Cordova']
# ['Angular', '.NET Core', 'Node.js', 'Xamarin']
# ['Node.js']
# ['Node.js']
# ['Node.js', 'React']
# ['Django', 'Node.js', 'React', 'TensorFlow', 'Torch/PyTorch']
# ['Django', 'Hadoop', 'Node.js', 'TensorFlow', 'Torch/PyTorch']
# ['.NET Core']
# ['Angular', 'Node.js', 'React', 'Spring']
# ['Angular', '.NET Core', 'Node.js', 'Spark', 'Spring']
# ['Angular', 'Node.js']
# ['Angular', 'Node.js', 'Cordova']
# ['Angular', '.NET Core', 'Node.js', 'Cordova']
# ['Angular', '.NET Core']
# ['Django', 'Node.js', 'React', 'Cordova']
# ['Node.js', 'React', 'Xamarin']
# ['Spring']
# ['Node.js', 'React']
# ['Hadoop', 'Node.js', 'TensorFlow', 'Torch/PyTorch']
# ['React']
# ['.NET Core']
# ['Angular']
# ['Django']
# ['Angular', '.NET Core', 'Node.js', 'Cordova']
# ['Node.js', 'React']
# ['Angular', 'Node.js']
# ['React']
# ['Angular', 'Django', 'Node.js', 'React']
# ['Django', 'Node.js']
# ['Angular', '.NET Core', 'Node.js', 'Cordova', 'Spring']
# ['Angular', '.NET Core']
# ['Angular']
# ['Xamarin']
# ['Django']
# ['Node.js']
# ['Django', 'Node.js', 'React']
# ['Node.js', 'Cordova', 'Xamarin', 'Spring']
# ['Angular', 'Django', 'React', 'Spring']
# ['Node.js', 'React']
# ['Angular', 'Node.js', 'React', 'Cordova']
# ['Django', 'Hadoop']
# ['Spring']
# ['Angular']
# ['Node.js', 'React']
# ['Node.js', 'Spring']
# ['Node.js', 'React']
# ['Hadoop', 'React', 'Spark', 'TensorFlow']
# ['Hadoop', 'Spark']
# ['.NET Core', 'Xamarin']
# ['Hadoop', 'Spark', 'TensorFlow']
# ['Node.js']
# ['Django', 'Node.js']
# ['Angular', 'Hadoop', 'Spark', 'Spring']
# ['Angular', '.NET Core', 'Node.js', 'Cordova', 'Xamarin', 'Spring']
# ['Angular', 'Node.js', 'React']
# ['Node.js', 'React']
# ['Node.js']
# ['Django', 'Hadoop']
# ['Node.js', 'Cordova']
# ['Hadoop', 'Node.js', 'React', 'Spring']
# ['Angular', 'Hadoop', 'Node.js', 'React', 'Spring', 'TensorFlow']
# ['React', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['Django', 'Node.js']
# ['Cordova']
# ['Django', 'Spring']
# ['Angular']
# ['Node.js', 'Spring']
# ['Django']
# ['Node.js', 'React']
# ['.NET Core', 'Node.js']
# ['.NET Core', 'Hadoop', 'Spark', 'Cordova']
# ['Angular']
# ['Angular']
# ['Angular', 'Node.js', 'React']
# ['Angular']
# ['Angular', 'Node.js', 'React', 'Cordova']
# ['Angular', '.NET Core', 'Node.js']
# ['Node.js', 'React']
# ['Node.js', 'React']
# ['Angular', '.NET Core']
# ['Angular', 'Django', 'Hadoop', 'Node.js', 'React', 'Spring']
# ['Node.js']
# ['.NET Core', 'Node.js']
# ['Node.js', 'Spring']
# ['Angular', 'Node.js', 'React', 'Spring', 'TensorFlow']
# ['React']
# ['Node.js']
# ['Django', 'Hadoop', 'Node.js', 'React']
# ['Angular', 'Django', 'Node.js', 'React', 'Cordova']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['Hadoop', 'Node.js', 'React', 'Spark', 'TensorFlow']
# ['.NET Core', 'Django']
# ['Angular', 'Node.js']
# ['Django']
# ['Angular']
# ['Spark']
# ['Node.js']
# ['Angular', '.NET Core', 'Hadoop', 'Node.js']
# ['Angular', '.NET Core']
# ['.NET Core', 'Node.js']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core', 'Spring']
# ['Node.js', 'React', 'Spark', 'Spring']
# ['.NET Core', 'Xamarin']
# ['.NET Core']
# ['.NET Core']
# ['Spring']
# ['.NET Core']
# ['Spring']
# ['Spark']
# ['Spring']
# ['Hadoop', 'Spark']
# ['Xamarin']
# ['Angular', 'Django', 'Cordova']
# ['Node.js']
# ['Hadoop', 'Node.js', 'Spark']
# ['React']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js']
# ['Spring']
# ['Angular', 'Node.js']
# ['Django', 'Hadoop', 'React']
# ['Django', 'React']
# ['Angular']
# ['Django', 'Node.js', 'Torch/PyTorch']
# ['Angular']
# ['Node.js']
# ['Angular', 'Xamarin']
# ['Node.js']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core']
# ['TensorFlow']
# ['Django']
# ['Angular', 'Node.js', 'Cordova', 'Spring']
# ['Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core']
# ['Spark', 'Spring']
# ['Node.js', 'Spring']
# ['Angular', 'Node.js', 'React', 'Xamarin']
# ['Node.js']
# ['Angular', 'Node.js', 'Spark']
# ['Angular', 'Node.js', 'Cordova', 'Spring']
# ['Angular', 'React']
# ['Angular', 'Node.js', 'React']
# ['Node.js', 'React']
# ['Angular', 'Node.js', 'Spring']
# ['.NET Core', 'React']
# ['Angular']
# ['Django', 'Node.js']
# ['.NET Core']
# ['Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js', 'Cordova', 'Xamarin', 'Spring']
# ['Angular', '.NET Core']
# ['.NET Core', 'Xamarin']
# ['.NET Core', 'Django', 'Xamarin']
# ['Angular', 'Node.js', 'Cordova']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Cordova', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js']
# ['Node.js']
# ['Angular', 'Cordova']
# ['React', 'Cordova']
# ['Angular', 'React']
# ['Node.js']
# ['Angular', 'Node.js', 'Cordova']
# ['Node.js', 'React']
# ['Node.js']
# ['.NET Core', 'Node.js']
# ['Django']
# ['Angular', '.NET Core', 'Node.js', 'Spring']
# ['Node.js']
# ['React']
# ['Django', 'TensorFlow']
# ['Django', 'React', 'Xamarin']
# ['Node.js']
# ['.NET Core', 'Django']
# ['.NET Core']
# ['.NET Core', 'Spring']
# ['Django', 'Node.js', 'React', 'Spark']
# ['Angular', '.NET Core', 'Django', 'Node.js', 'React']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core', 'Node.js']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core']
# ['Node.js']
# ['Django', 'Node.js', 'React']
# ['Node.js']
# ['.NET Core', 'Hadoop', 'Spark']
# ['React']
# ['React']
# ['.NET Core', 'Xamarin']
# ['.NET Core']
# ['Django']
# ['React']
# ['React']
# ['Node.js']
# ['Angular', 'Node.js', 'React', 'Cordova']
# ['Node.js', 'React']
# ['Spring']
# ['.NET Core']
# ['Node.js']
# ['.NET Core', 'Node.js', 'React', 'TensorFlow']
# ['Django', 'Spark', 'TensorFlow']
# ['Node.js', 'React']
# ['Angular', 'Spring']
# ['Angular', '.NET Core']
# ['Xamarin']
# ['Angular', '.NET Core', 'Node.js']
# ['React', 'Spring']
# ['Node.js']
# ['Angular', '.NET Core', 'Xamarin']
# ['Angular', 'Node.js']
# ['Angular', 'Spring']
# ['Angular', 'Node.js', 'React', 'Cordova']
# ['Angular', '.NET Core', 'Hadoop', 'Node.js', 'React', 'TensorFlow']
# ['Angular', 'Spring']
# ['Django', 'Node.js', 'React', 'Spring']
# ['Angular']
# ['Node.js', 'React']
# ['.NET Core']
# ['Node.js', 'React']
# ['Node.js']
# ['Angular', 'Node.js', 'React', 'TensorFlow']
# ['Node.js']
# ['.NET Core']
# ['Spring']
# ['Node.js', 'React']
# ['Angular', 'Spring']
# ['Hadoop', 'Node.js', 'React']
# ['Django']
# ['Node.js', 'React', 'Spring']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Cordova', 'Xamarin']
# ['Spring']
# ['Node.js']
# ['.NET Core']
# ['Angular', 'Django']
# ['Django', 'Node.js']
# ['Angular']
# ['Node.js', 'React', 'TensorFlow']
# ['Node.js']
# ['Angular', '.NET Core', 'Node.js', 'Xamarin', 'Spring']
# ['.NET Core']
# ['Node.js', 'React', 'Spring']
# ['.NET Core', 'Node.js', 'React', 'TensorFlow']
# ['.NET Core']
# ['Angular', 'Django', 'Node.js', 'Spark', 'TensorFlow']
# ['Xamarin']
# ['Angular', 'Node.js', 'Cordova', 'Spring', 'TensorFlow']
# ['Angular', 'Spring']
# ['Angular', '.NET Core', 'Node.js']
# ['TensorFlow']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Cordova', 'Spring', 'TensorFlow']
# ['Node.js']
# ['.NET Core']
# ['Node.js']
# ['Node.js', 'React']
# ['Hadoop', 'Spark']
# ['Node.js']
# ['React', 'Spring']
# ['Django']
# ['Node.js', 'React']
# ['Node.js', 'React']
# ['Node.js']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Spring']
# ['Node.js', 'React']
# ['.NET Core']
# ['Angular', 'Node.js', 'TensorFlow']
# ['Angular']
# ['Django', 'Node.js']
# ['Django', 'Spring']
# ['Node.js', 'React']
# ['Node.js', 'React']
# ['Angular', 'Node.js', 'Torch/PyTorch']
# ['.NET Core', 'React', 'Xamarin']
# ['.NET Core', 'Node.js']
# ['Angular', 'Cordova', 'Xamarin', 'Spring']
# ['Hadoop', 'Spark']
# ['Node.js', 'React']
# ['Angular', 'Node.js', 'React', 'Spark', 'Spring']
# ['Django', 'Node.js']
# ['Hadoop', 'Spark']
# ['Angular', 'Node.js', 'React']
# ['.NET Core']
# ['.NET Core', 'Node.js']
# ['.NET Core']
# ['.NET Core']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', '.NET Core']
# ['Node.js', 'React', 'Spring']
# ['Node.js']
# ['Angular', 'Node.js', 'Cordova', 'Xamarin', 'TensorFlow']
# ['Angular', 'Node.js', 'React', 'Cordova']
# ['Django']
# ['Angular', 'Node.js', 'React', 'Cordova']
# ['Angular', '.NET Core', 'Node.js']
# ['.NET Core']
# ['.NET Core', 'Node.js', 'Xamarin']
# ['Cordova', 'Spring']
# ['Angular', 'Node.js', 'Spring']
# ['Node.js']
# ['.NET Core', 'Node.js', 'Xamarin']
# ['.NET Core']
# ['.NET Core']
# ['Angular', 'Node.js', 'React']
# ['Angular', 'Node.js', 'Cordova', 'Xamarin']
# ['.NET Core', 'Django', 'Node.js', 'React']
# ['Angular', 'Node.js']
# ['Cordova']
# ['React']
# ['Node.js', 'React']
# ['Hadoop', 'Spark', 'TensorFlow']
# ['.NET Core', 'Spring', 'TensorFlow']
# ['Django', 'Node.js']
# ['.NET Core']
# ['Node.js']
# ['Angular', 'Node.js', 'React']
# ['.NET Core', 'Xamarin']
# ['Angular', 'Spring']
# ['Node.js', 'Cordova']
# ['Node.js', 'Xamarin']
# ['Angular', 'React']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['Angular', 'TensorFlow']
# ['Angular', 'Node.js']
# ['React']
# ['Spring']
# ['Angular', 'Node.js', 'Cordova']
# ['Spark', 'Spring']
# ['Node.js', 'React']
# ['Angular', 'Node.js', 'Spring']
# ['Angular', 'Node.js', 'React']
# ['Angular', 'Node.js', 'React']
# ['Spring']
# ['Node.js']
# ['.NET Core', 'Node.js']
# ['.NET Core', 'Node.js']
# ['Node.js', 'React']
# ['Angular', '.NET Core', 'Django', 'Node.js', 'React']
# ['.NET Core', 'Spring', 'TensorFlow']
# ['Django']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', 'TensorFlow']
# ['Angular', 'Node.js', 'React']
# ['Node.js', 'React', 'Spring']
# ['.NET Core', 'Cordova', 'Xamarin']
# ['Angular', '.NET Core', 'Node.js']
# ['Angular', 'Node.js', 'Spring']
# ['Hadoop']
# ['Angular']
# ['Django']
# ['Angular', '.NET Core', 'Node.js', 'React', 'Xamarin']
# ['Angular', 'React']
# ['Django']
# ['Angular', 'Node.js']
# ['Node.js']
# ['TensorFlow']
# ['.NET Core', 'Node.js']
# ['.NET Core', 'Xamarin']
# ['Angular', 'Django', 'Node.js', 'React', 'Cordova']
# ['Node.js']
# ['Django', 'React']
# ['Angular', '.NET Core', 'Node.js', 'React']
# ['Angular', '.NET Core']
# ['.NET Core', 'Node.js', 'React', 'Xamarin', 'TensorFlow']
# ['Angular', 'Node.js']
# ['Angular', '.NET Core', 'Node.js', 'React', 'TensorFlow']
# ['Node.js', 'React']
# ['Angular', 'Node.js', 'Cordova']
# ['Node.js', 'React', 'TensorFlow']
# ['Angular', 'Cordova']
# ['Django', 'Node.js', 'React', 'TensorFlow', 'Torch/PyTorch']
# ['.NET Core', 'Node.js']

# %% [markdown]
# ### Build Graph on Neo4j

# %%
from neo4j import GraphDatabase
import logging
from neo4j.exceptions import ServiceUnavailable

class App:

    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        # Don't forget to close the driver connection when you are finished with it
        self.driver.close()

    def create_friendship(self, person1_name, person2_name):
        with self.driver.session() as session:
            # Write transactions allow the driver to handle retries and transient errors
            result = session.write_transaction(
                self._create_and_return_friendship, person1_name, person2_name)
            for row in result:
                print("Created friendship between: {p1}, {p2}".format(p1=row['p1'], p2=row['p2']))

    @staticmethod
    def _create_and_return_friendship(tx, person1_name, person2_name):
        # To learn more about the Cypher syntax, see https://neo4j.com/docs/cypher-manual/current/
        # The Reference Card is also a good resource for keywords https://neo4j.com/docs/cypher-refcard/current/
        query = (
            "MERGE (p1:Person { name: $person1_name }) "
            "MERGE (p2:Person { name: $person2_name }) "
            "CREATE (p1)-[:livesIn]->(p2) "
            "RETURN p1, p2"
        )
        result = tx.run(query, person1_name=person1_name, person2_name=person2_name)
        try:
            return [{"p1": row["p1"]["name"], "p2": row["p2"]["name"]}
                    for row in result]
        # Capture any errors along with the query and data for traceability
        except ServiceUnavailable as exception:
            logging.error("{query} raised an error: \n {exception}".format(
                query=query, exception=exception))
            raise

    def find_person(self, person_name):
        with self.driver.session() as session:
            result = session.read_transaction(self._find_and_return_person, person_name)
            for row in result:
                print("Found person: {row}".format(row=row))

    @staticmethod
    def _find_and_return_person(tx, person_name):
        query = (
            "MATCH (p:Person) "
            "WHERE p.name = $person_name "
            "RETURN p.name AS name"
        )
        result = tx.run(query, person_name=person_name)
        return [row["name"] for row in result]


if __name__ == "__main__":
    # Aura queries use an encrypted connection using the "neo4j+s" URI scheme
    uri = "neo4j://localhost:7687"
    user = "neo4j"
    password = "amit"
    app = App(uri, user, password)
    
    for index,rows in df1.iterrows():
        res=rows['Respondent'] 
        contr=rows['Country']
        app.create_friendship(res, contr)
    app.find_person("India")
    app.close()
# Out:
# Unable to retrieve routing information
# Transaction failed and will be retried in 0.9519402568504414s (Unable to retrieve routing information)
# Unable to retrieve routing information
# Transaction failed and will be retried in 2.3851653518489266s (Unable to retrieve routing information)
# Unable to retrieve routing information
# Transaction failed and will be retried in 4.167725529206667s (Unable to retrieve routing information)
# Unable to retrieve routing information
# Transaction failed and will be retried in 9.343769134660267s (Unable to retrieve routing information)
# Unable to retrieve routing information
# ---------------------------------------------------------------------------
# ServiceUnavailable                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7420/1810784167.py in <module>
#      67         res=rows['Respondent']
#      68         contr=rows['Country']
# ---> 69         app.create_friendship(res, contr)
#      70     app.find_person("India")
#      71     app.close()
#
# ~\AppData\Local\Temp/ipykernel_7420/1810784167.py in create_friendship(self, person1_name, person2_name)
#      15         with self.driver.session() as session:
#      16             # Write transactions allow the driver to handle retries and transient errors
# ---> 17             result = session.write_transaction(
#      18                 self._create_and_return_friendship, person1_name, person2_name)
#      19             for row in result:
#
# c:\users\hp\appdata\local\programs\python\python310\lib\site-packages\neo4j\work\simple.py in write_transaction(self, transaction_function, *args, **kwargs)
#     419         :return: a result as returned by the given unit of work
#     420         """
# --> 421         return self._run_transaction(WRITE_ACCESS, transaction_function, *args, **kwargs)
#     422
#     423
#
# c:\users\hp\appdata\local\programs\python\python310\lib\site-packages\neo4j\work\simple.py in _run_transaction(self, access_mode, transaction_function, *args, **kwargs)
#     350
#     351         if errors:
# --> 352             raise errors[-1]
#     353         else:
#     354             raise ServiceUnavailable("Transaction failed")
#
# c:\users\hp\appdata\local\programs\python\python310\lib\site-packages\neo4j\work\simple.py in _run_transaction(self, access_mode, transaction_function, *args, **kwargs)
#     320         while True:
#     321             try:
# --> 322                 self._open_transaction(access_mode=access_mode, metadata=metadata, timeout=timeout)
#     323                 tx = self._transaction
#     324                 try:
#
# c:\users\hp\appdata\local\programs\python\python310\lib\site-packages\neo4j\work\simple.py in _open_transaction(self, access_mode, metadata, timeout)
#     253     def _open_transaction(self, *, access_mode, metadata=None,
#     254                           timeout=None):
# --> 255         self._connect(access_mode=access_mode)
#     256         self._transaction = Transaction(
#     257             self._connection, self._config.fetch_size,
#
# c:\users\hp\appdata\local\programs\python\python310\lib\site-packages\neo4j\work\simple.py in _connect(self, access_mode)
#     106         if access_mode is None:
#     107             access_mode = self._config.default_access_mode
# --> 108         super()._connect(access_mode)
#     109
#     110     def _collect_bookmark(self, bookmark):
#
# c:\users\hp\appdata\local\programs\python\python310\lib\site-packages\neo4j\work\__init__.py in _connect(self, access_mode)
#      71                 # we shall use this database explicitly for all subsequent
#      72                 # actions within this session.
# ---> 73                 self._pool.update_routing_table(
#      74                     database=self._config.database,
#      75                     imp_user=self._config.impersonated_user,
#
# c:\users\hp\appdata\local\programs\python\python310\lib\site-packages\neo4j\io\__init__.py in update_routing_table(self, database, imp_user, bookmarks, database_callback)
#    1101             # None of the routers have been successful, so just fail
#    1102             log.error("Unable to retrieve routing information")
# -> 1103             raise ServiceUnavailable("Unable to retrieve routing information")
#    1104
#    1105     def update_connection_pool(self, *, database):
#
# ServiceUnavailable: Unable to retrieve routing information
